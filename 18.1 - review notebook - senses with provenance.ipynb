# %% [markdown]
# # Review notebook for Harvesting Senses with Provenance Information
#
# Functions reviewed in this Notebook:
#
# - `get_provenance_by_semantic_class` (helper)
# - `extend_from_lemma` (main)
#
#
# Part of:
# - `utils.dataset_download`
#
#
# Creator: Kaspar Beelen
#
# Reviewer(s):

# %% [markdown]
# These functions assume:
#     - a pickled dataframe with information harvested from the OED word endpoint for a given lemma id
#
# What these functions should do:
#     - for a given lemma id (e.g. `machine_nn01` saved in pickled data)
#     - get all senses
#     - for each of the senses get synonyms
#     - for each of the senses + synonyms, get all branches (siblings and descedants
#     - keep track of the relation between the initial lemma and sense harvested (this is saved in provenance and provenance_type column
#     - for more documentation please refer to the code and this notebook

# %%
# !git branch
# Out:
#   1-dataframe
#   19-machine-tagger
#   3-group-senses
# * 4-semantic-provenance
#   dev
#   master
#   oed-experiments

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
from utils.dataset_download import *
import pickle
import json
from pathlib import Path, PosixPath
import pandas as pd

# %% [markdown]
# # Load credentials, set paths and arguments

# %%
# import API credentials
with open('oed_experiments/oed_credentials.json') as f:
    auth = json.load(f)

# %%
# define lemma
lemma_id = "machine_nn01"

# %%
dp = "../data"

# %%
save_path = Path(dp)
save_path.mkdir(exist_ok=True)

# %%
start,end = 1750,1950
lemma_id = 'machine_nn01'

# %% [markdown]
# ## Run function

# %%
extended_df = extend_from_lemma(auth,lemma_id,start,end)

# %%
extended_df.head(3)

# %%
extended_df.shape

# %% [markdown]
# # Inspect functions
#
# - `get_provenance_by_semantic_class`

# %%
def get_provenance_by_semantic_class(row: pd.Series) -> list:
    """
    decide on the relation between the sense and the target querry
    here we use the lowest semantic class id to decide on the relation
    
    if last semantic class id (sc_ids[-1]) == provenance id: then sense is sibling of provenance id
    elif provenance semantic class id in the list of semantic class last ids
    (but provenance not the last one): then sense is descendant of provenance id
    Argument:
        row (pd.Series): row of dataframe obtained from branchsenses endpoint
    
    Returns:
        nested listed in the format of [lowest semantic class id, relation, provenance semantic class id]
            in other words it said that for a given sense (which can have multiple semantic class ids)
            the lowest semantic class id stands in the relation "sibling" or "descendant" of the 
            provenance semantic class id
    """
    
    provenance = []
    
    # one sense can belong to multiple semantic class ids
    for sc_ids in row.semantic_class_ids:
        relation = ''
        
        # scenario 1
        # if the last id equals provenance, the relation is sibling
        if sc_ids[-1] == row.provenance_pivot:
            relation = 'sibling'
        
        # scenario 2
        # if not, then the relation is descendant
        elif (row.provenance_pivot in sc_ids):
            relation = 'descendant'
        
        # exclude other relations
        if relation:
            provenance.append([sc_ids[-1], relation, row.provenance_pivot])
    
    # double check, each sense SHOULD have a provenance
    # if not this will print a warning message
    if not provenance:
        print(f'Warning: No descendants or siblings found for {row.id}')
 
    return provenance

# %% [markdown]
# Inspect function `extend_from_lemma`
#
# Below we put the function in seperate cells, to facilitate scrutinizing individual steps.

# %%
senses_df = pd.read_pickle(f"./data/senses_{lemma_id}.pickle")
senses_df.head()

# %%
# helper function to get last element in a nested list
get_last_id = lambda nested_list :[l[-1] for l in nested_list]
    
# load seed query dataframe or download from api
lemma_path = f"./data/senses_{lemma_id}.pickle"
if Path(lemma_path).is_file():
    print(f'Loading senses for {lemma_id} from pickle.')
    query_df = pd.read_pickle(lemma_path)
else:
    print(f'Dowloading senses for {lemma_id} from OED API.')
    sense_json = query_oed(auth,'word',lemma_id,flags='include_senses=true&include_quotations=true')
    # convert the json in a dataframe
    query_df = convert_json_to_dataframe(sense_json)
    # save the datafram as pickle
    query_df.to_pickle(f"./data/senses_{lemma_id}.pickle")
    
# use the sense endpoint to ensure all information 
# can be properly concatenated in one dataframe
    
# retrieve all sense ids
query_sense_ids = query_df.id.unique()

# %%
# get all senses by sense id
print(f"Get all sense for the lemma {lemma_id}")
seeds = [(s,query_oed(auth,'sense',s,
                flags=f"current_in='{start}-{end}'&limit=1000", # probably "current_in" not needed here see APi
                verbose=False)) # set verbose to True to see the url request
                    for s in tqdm(query_sense_ids)]

# %%
# convert to dataframe
seeds_df = pd.DataFrame([seed['data'] for s_id,seed in seeds])

# seed_df contains all the senses of the word machine_nn01
# we distinguish between provenance and provenance_type
# provenance will refer to specific word, sense of semantic class ids
# provenance_type will distinguish between different types of extension
# define provenance, these words are "seed"
seeds_df['provenance'] = [[[i,'seed',lemma_id]] for i in seeds_df.id] # for the seed sense we use the id of the word machine_nn0
                                       # we use list here, reason is explained later, see provenance of synonyms
seeds_df['provenance_type'] = 'seed' # categorize these lemmas as seed

# %%
# get all synonyms for the seed senses
# reminder synonyms uses same function as the /senses/ endpoint, flags should work here
print(f"Get all synonyms of the senses listed in {lemma_id}")
synonyms = [(s,query_oed(auth,'sense',s,
                level='synonyms',
                flags=f"current_in='{start}-{end}'&limit=1000"))
                        for s in tqdm(query_sense_ids)]

# %%
# transform list of synonyms to a dataframe
synonyms_df = pd.DataFrame([s for s_id,syn in synonyms for s in syn['data']])
    
# for synonyms the provenance_type is set to "synonym"
synonyms_df['provenance_type'] = 'synonym'
# for synonyms we refer the sense_id via which this synonym was retrieved
synonyms_df['provenance'] = [[[s['id'],'synonym',s_id]] for s_id,syn in synonyms for s in syn['data']]

# %%
# seed + synonyms constitute the nucleas of our query
# these are saved in the core_df
# shape should be 485 (synonyms senses) + 26 (seed senses)
core_df = pd.concat([seeds_df,synonyms_df],sort=True)
    
# branch out from there
# we save the lowest level of the semantic_class_last_id columns
core_df['semantic_class_last_id'] = core_df['semantic_class_ids'].apply(get_last_id)

# %%
# retrieve all the _lowest_ (or last) semantic class ids for the core senses so far
semantic_class_ids = set([s for l in core_df.semantic_class_last_id.to_list() for s in l])

# %%
# now, we use the descendants endpoint
# for each lowest semantic class id
# we get all "descendants" which according the API documentation
# returns an array of senses that belong to the semantic class
# specified by ID, plus senses that belong to its child and descendant classes.
print("Get all branches for seed senses and synonyms")
branches = [(idx,query_oed(auth,'semanticclass', idx, 
                        level='branchsenses', # 
                        flags=f"current_in='{start}-{end}'&limit=1000"))
                            for idx in tqdm(semantic_class_ids)]

# %%
# convert API response to dataframe
branches_df = pd.DataFrame([s for idx,branch in branches for s in branch['data']])
    
# ISSUE: again we have duplicate 
# senses here, as some appear multiple time as
# in the same semantic class (or as descendant)
    
# provenance_type is branch with semantic class id 
# that was use for retrieving the sense is the provenance
branches_df['provenance_type'] = 'branch'
    
# we create a provenance_pivot columsn, which shows
# the semantic class id via which the sense was retrieved
branches_df['provenance_pivot'] = [idx for idx, branch in branches for s in branch['data']]

# %%
# now there are two scenarios to specify for the pro
# both scenarios can apply to one sense
# if last semantic class id (sc_ids[-1]) == provenance id: then sense is sibling of provenance id
# elif provenance semantic class id in the list of semantic class last ids
# (but provenance not the last one): then sense is descendant of provenance id
    
branches_df['provenance'] = branches_df.apply(get_provenance_by_semantic_class,axis=1)
    
# drop the provenance_pivot column
branches_df.drop('provenance_pivot',axis=1,inplace=True)
    
# concatenate core and branch senses
# ISSUE: have a closer look at the warning message
extended_df = pd.concat([core_df,branches_df],sort=True)

# to check if rows match
#extended_df.shape[0] == core_df.shape[0] + branches_df.shape[0]
# save dataframe as pickle
extended_df.to_pickle(f"./data/extended_{lemma_id}.pickle")

# %% [markdown]
# ## Fin.

# %%
def add_unrelated_senses(path):
extended_df = pd.read_pickle(f"./data/extended_{lemma_id}.pickle")

# %%
word_id = list(set(extended_df.word_id))

# %%
word_id[100]
# Out:
# 'carry_nn01'

# %%
res = query_oed(auth,'word',word_id[100],
                level='quotations',
                #flags=f"current_in='{start}-{end}'&limit=1000"
               )

# %%
pd.DataFrame(res['data'])
# Out:
#                       id                                               text  \
# 0     carry_nn01-9991081  {'keyword': 'carry', 'full_text': 'On the last...
# 1     carry_nn01-9991130  {'keyword': 'carry', 'full_text': 'Shee is a b...
# 2     carry_nn01-9991292  {'keyword': 'carry', 'full_text': 'I min'..sin...
# 3     carry_nn01-9991300  {'keyword': 'carry', 'full_text': 'Mirk and ra...
# 4     carry_nn01-9991263  {'keyword': 'carries', 'full_text': 'Still tow...
# 5     carry_nn01-9991089  {'keyword': 'carrie', 'full_text': 'Alexander ...
# 6     carry_nn01-9991271  {'keyword': 'carry', 'full_text': 'The clouds ...
# 7     carry_nn01-9991147  {'keyword': 'Carry', 'full_text': 'At the halt...
# 8   carry_nn01-307616029  {'keyword': 'carry', 'full_text': 'From this p...
# 9     carry_nn01-9991281  {'keyword': 'carry', 'full_text': 'The directi...
# 10    carry_nn01-9991164  {'keyword': 'carry', 'full_text': 'Our positio...
# 11    carry_nn01-9991242  {'keyword': 'carry', 'full_text': 'We crossed ...
# 12    carry_nn01-9991096  {'keyword': 'Carry', 'full_text': 'Carry, a ki...
# 13    carry_nn01-9991313  {'keyword': 'carry', 'full_text': 'She got a g...
# 14    carry_nn01-9991117  {'keyword': 'Carry', 'full_text': 'Carry, a we...
# 15    carry_nn01-9991250  {'keyword': 'carries', 'full_text': 'Boats cam...
# 16    carry_nn01-9991181  {'keyword': 'carry', 'full_text': 'Getting bot...
# 17    carry_nn01-9991104  {'keyword': 'carry', 'full_text': 'One of the....
# 18    carry_nn01-9991189  {'keyword': 'carry', 'full_text': 'Carry, the ...
# 19    carry_nn01-9991200  {'keyword': 'carry', 'full_text': 'A well hit ...
# 20    carry_nn01-9991208  {'keyword': 'carry', 'full_text': 'A long carr...
# 21    carry_nn01-9991216  {'keyword': 'carry', 'full_text': 'The carry a...
# 22    carry_nn01-9991324  {'keyword': 'carry', 'full_text': 'We hoped th...
# 23    carry_nn01-9991379  {'keyword': 'carry', 'full_text': 'The 20-year...
# 24    carry_nn01-9991335  {'keyword': 'carry', 'full_text': 'I'm having ...
# 25    carry_nn01-9991224  {'keyword': 'carry', 'full_text': 'You must no...
# 26    carry_nn01-9991387  {'keyword': 'carries', 'full_text': 'Grisham, ...
# 27    carry_nn01-9991345  {'keyword': 'carry', 'full_text': 'The barman,...
# 28    carry_nn01-9991353  {'keyword': 'carry', 'full_text': 'Schmitty hu...
# 29    carry_nn01-9991396  {'keyword': 'carry', 'full_text': 'Raimey..is ...
# 30    carry_nn01-9991362  {'keyword': 'carries', 'full_text': 'Basque ga...
# 31    carry_nn01-9991405  {'keyword': 'carries', 'full_text': 'Dupree's ...
#
#     year  lemma                                             source  \
# 0   1605  carry  {'title': 'Annales', 'author': 'J. Stow', 'gen...
# 1   1618  carry  {'title': 'New & 2nd Bk. Falconrie', 'author':...
# 2   1788  carry  {'title': 'Poems & Epist.', 'author': 'E. Pick...
# 3   1807  carry  {'title': 'Sleeping, Maggie', 'author': 'R. Ta...
# 4   1819  carry  {'title': 'Vestriad', 'author': 'H. Busk', 'ge...
# 5   1820  carry  {'title': 'Caldeonian Merc.', 'author': None, ...
# 6   1828  carry  {'title': 'Blackwood's Edinb. Mag.', 'author':...
# 7   1833  carry  {'title': 'Regulations Instr. Cavalry', 'autho...
# 8   1857  carry  {'title': 'Knickerbocker', 'author': None, 'ge...
# 9   1857  carry  {'title': 'Madeira', 'author': 'R. White', 'ge...
# 10  1858  carry  {'title': 'Oceola', 'author': 'M. Reid', 'gend...
# 11  1860  carry  {'title': 'All Year Round', 'author': None, 'g...
# 12  1863  carry  {'title': 'Provinc. Danby', 'author': 'J. C. A...
# 13  1880  carry  {'title': 'Lowland Lore', 'author': 'G. Fraser...
# 14  1881  carry  {'title': 'Antrim & Down Gloss.', 'author': No...
# 15  1884  carry  {'title': 'Harper's Mag.', 'author': None, 'ge...
# 16  1887  carry  {'title': 'Art of Golf', 'author': 'W. G. Simp...
# 17  1887  carry  {'title': 'Sc. Leader', 'author': None, 'gende...
# 18  1890  carry  {'title': 'Gloss.', 'author': None, 'gender': ...
# 19  1896  carry  {'title': 'Game of Golf', 'author': 'W. Park',...
# 20  1896  carry  {'title': 'Game of Golf', 'author': 'W. Park',...
# 21  1899  carry  {'title': 'Golf Illustrated', 'author': None, ...
# 22  1925  carry  {'title': None, 'author': 'E. F. Norton', 'gen...
# 23  1949  carry  {'title': 'Pittsburgh Press', 'author': None, ...
# 24  1951  carry  {'title': 'Lagoon', 'author': 'J. Frame', 'gen...
# 25  1953  carry  {'title': 'On Golf', 'author': 'B. Locke', 'ge...
# 26  1962  carry  {'title': 'Springfield (Mass.) Republican', 'a...
# 27  1966  carry  {'title': 'Cannonball', 'author': 'J. Chamier'...
# 28  1967  carry  {'title': 'Corpse Candle', 'author': '‘G. Bagb...
# 29  1970  carry  {'title': 'Globe & Mail (Toronto)', 'author': ...
# 30  1979  carry  {'title': 'United States 1980–1', 'author': No...
# 31  1984  carry  {'title': 'News (Mexico City)', 'author': None...
#
#                                               oed_url     word_id  \
# 0     https://www.oed.com/view/Entry/28251#eid9991081  carry_nn01
# 1     https://www.oed.com/view/Entry/28251#eid9991130  carry_nn01
# 2     https://www.oed.com/view/Entry/28251#eid9991292  carry_nn01
# 3     https://www.oed.com/view/Entry/28251#eid9991300  carry_nn01
# 4     https://www.oed.com/view/Entry/28251#eid9991263  carry_nn01
# 5     https://www.oed.com/view/Entry/28251#eid9991089  carry_nn01
# 6     https://www.oed.com/view/Entry/28251#eid9991271  carry_nn01
# 7     https://www.oed.com/view/Entry/28251#eid9991147  carry_nn01
# 8   https://www.oed.com/view/Entry/28251#eid307616029  carry_nn01
# 9     https://www.oed.com/view/Entry/28251#eid9991281  carry_nn01
# 10    https://www.oed.com/view/Entry/28251#eid9991164  carry_nn01
# 11    https://www.oed.com/view/Entry/28251#eid9991242  carry_nn01
# 12    https://www.oed.com/view/Entry/28251#eid9991096  carry_nn01
# 13    https://www.oed.com/view/Entry/28251#eid9991313  carry_nn01
# 14    https://www.oed.com/view/Entry/28251#eid9991117  carry_nn01
# 15    https://www.oed.com/view/Entry/28251#eid9991250  carry_nn01
# 16    https://www.oed.com/view/Entry/28251#eid9991181  carry_nn01
# 17    https://www.oed.com/view/Entry/28251#eid9991104  carry_nn01
# 18    https://www.oed.com/view/Entry/28251#eid9991189  carry_nn01
# 19    https://www.oed.com/view/Entry/28251#eid9991200  carry_nn01
# 20    https://www.oed.com/view/Entry/28251#eid9991208  carry_nn01
# 21    https://www.oed.com/view/Entry/28251#eid9991216  carry_nn01
# 22    https://www.oed.com/view/Entry/28251#eid9991324  carry_nn01
# 23    https://www.oed.com/view/Entry/28251#eid9991379  carry_nn01
# 24    https://www.oed.com/view/Entry/28251#eid9991335  carry_nn01
# 25    https://www.oed.com/view/Entry/28251#eid9991224  carry_nn01
# 26    https://www.oed.com/view/Entry/28251#eid9991387  carry_nn01
# 27    https://www.oed.com/view/Entry/28251#eid9991345  carry_nn01
# 28    https://www.oed.com/view/Entry/28251#eid9991353  carry_nn01
# 29    https://www.oed.com/view/Entry/28251#eid9991396  carry_nn01
# 30    https://www.oed.com/view/Entry/28251#eid9991362  carry_nn01
# 31    https://www.oed.com/view/Entry/28251#eid9991405  carry_nn01
#
#               sense_id datestring  first_in_word        oed_reference  \
# 0   carry_nn01-9991075       1605           True  carry, n., sense 1b
# 1   carry_nn01-9991125       1618          False   carry, n., sense 2
# 2   carry_nn01-9991289       1788          False  carry, n., sense 6b
# 3   carry_nn01-9991289    1807–10          False  carry, n., sense 6b
# 4   carry_nn01-9991259       1819          False  carry, n., sense 6a
# 5   carry_nn01-9991075       1820          False  carry, n., sense 1b
# 6   carry_nn01-9991259       1828          False  carry, n., sense 6a
# 7   carry_nn01-9991139       1833          False   carry, n., sense 3
# 8   carry_nn01-9991233       1857          False   carry, n., sense 5
# 9   carry_nn01-9991259       1857          False  carry, n., sense 6a
# 10  carry_nn01-9991156       1858          False  carry, n., sense 4a
# 11  carry_nn01-9991233       1860          False   carry, n., sense 5
# 12  carry_nn01-9991075       1863          False  carry, n., sense 1b
# 13  carry_nn01-9991309       1880          False  carry, n., sense 7a
# 14  carry_nn01-9991112       1881          False  carry, n., sense 1c
# 15  carry_nn01-9991233       1884          False   carry, n., sense 5
# 16  carry_nn01-9991172       1887          False  carry, n., sense 4b
# 17  carry_nn01-9991075       1887          False  carry, n., sense 1b
# 18  carry_nn01-9991172       1890          False  carry, n., sense 4b
# 19  carry_nn01-9991172       1896          False  carry, n., sense 4b
# 20  carry_nn01-9991172       1896          False  carry, n., sense 4b
# 21  carry_nn01-9991172       1899          False  carry, n., sense 4b
# 22  carry_nn01-9991309       1925          False  carry, n., sense 7a
# 23  carry_nn01-9991370       1949          False  carry, n., sense 7b
# 24  carry_nn01-9991309       1951          False  carry, n., sense 7a
# 25  carry_nn01-9991172       1953          False  carry, n., sense 4b
# 26  carry_nn01-9991370       1962          False  carry, n., sense 7b
# 27  carry_nn01-9991309       1966          False  carry, n., sense 7a
# 28  carry_nn01-9991309       1967          False  carry, n., sense 7a
# 29  carry_nn01-9991370       1970          False  carry, n., sense 7b
# 30  carry_nn01-9991309       1979          False  carry, n., sense 7a
# 31  carry_nn01-9991370       1984          False  carry, n., sense 7b
#
#     first_in_sense
# 0             True
# 1             True
# 2             True
# 3            False
# 4             True
# 5            False
# 6            False
# 7             True
# 8             True
# 9            False
# 10            True
# 11           False
# 12           False
# 13            True
# 14            True
# 15           False
# 16            True
# 17           False
# 18           False
# 19           False
# 20           False
# 21           False
# 22           False
# 23            True
# 24           False
# 25           False
# 26           False
# 27           False
# 28           False
# 29           False
# 30           False
# 31           False
