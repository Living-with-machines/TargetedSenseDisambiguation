# %% [markdown]
# # Code for extracting synonyms from OED API

# %% [markdown]
# Author: Barbara McGillivray

# %% [markdown]
# ## Initialization

# %%
import requests
import json

# %% [markdown]
# Instructions from https://developer.oxforddictionaries.com/documentation/making-requests-to-the-api

# %%
with open('oed_credentials.json') as f:
    credentials = json.load(f)

app_id = credentials["app_id"]
app_key = credentials["app_key"]

# %% [markdown]
# Let us look at the entry for "machine" in the OED:

# %%
#url = "https://od-api.oxforddictionaries.com/api/v2/en/<language_code>/<word_id>"
url_lemma = "https://oed-researcher-api.oxfordlanguages.com/oed/api/v0.2/words/?lemma=machine"
r_lemma = requests.get(url_lemma, headers = {"app_id": app_id, "app_key": app_key})

# %%
print("code {}\n".format(r_lemma.status_code))
# Out:
# code 200

# %% [markdown]
# Let us inspect the output text:

# %%
print("text \n" + r_lemma.text)
# Out:
# text
# {"meta": {"total": 2, "count": 2, "offset": 0, "limit": 100, "provider": "Oxford University Press", "cite": "Oxford English Dictionary API, Oxford University Press, 0.0.0.0/oed/api/v0.2/words/?lemma=machine&offset=0&limit=100 . Accessed 15 September 2020"}, "links": {"self": "/oed/api/v0.2/words/?lemma=machine&offset=0&limit=100", "prev": null, "next": null, "first": "/oed/api/v0.2/words/?lemma=machine&offset=0&limit=100", "last": "/oed/api/v0.2/words/?lemma=machine&offset=0&limit=100"}, "data": [{"id": "machine_vb01", "band": 10, "meta": {"created": 1904, "revised": true, "updated": 2000}, "lemma": "machine", "oed_url": "https://www.oed.com/view/Entry/111851#eid38480197", "daterange": {"end": null, "start": 1450, "obsolete": false, "rangestring": "?c1450\u2014"}, "etymology": {"etymons": [{"word": "machiner", "language": "French"}, {"word": "machine", "language": "English", "target_id": "machine_nn01", "part_of_speech": "NN"}], "etymology_type": "borrowing", "etymon_language": [["European languages", "Italic", "Romance", "Italo-Western", "Gallo-Romance", "French"], ["English"]], "source_language": [["European languages", "Italic", "Romance", "Italo-Western", "Gallo-Romance", "French"], ["European languages", "Italic", "Latin"], ["English"]], "etymology_summary": "A borrowing from French."}, "first_use": "Life of St. Cuthbert", "frequency": [[1750, 0.071], [1760, 0.072], [1770, 0.076], [1780, 0.075], [1790, 0.078], [1800, 0.079], [1810, 0.079], [1820, 0.081], [1830, 0.084], [1840, 0.084], [1850, 0.096], [1860, 0.12], [1870, 0.2], [1880, 0.42], [1890, 0.69], [1900, 0.93], [1910, 1.3], [1920, 2.2], [1930, 2.7], [1940, 3.1], [1950, 3.8], [1960, 3.0], [1970, 2.9], [1980, 2.6], [1990, 2.5], [2000, 2.1], [2010, 1.9]], "sense_ids": ["machine_vb01-38480199", "machine_vb01-38480251", "machine_vb01-38480267", "machine_vb01-38480282", "machine_vb01-38480402", "machine_vb01-38480424", "machine_vb01-38480453", "machine_vb01-38480455"], "definition": "transitive. To form, make, or operate on by means of a machine; to print, engrave, cut, shape, or sew by means of a machine. Also with in, off, etc.", "main_entry": true, "inflections": [{"region": "British", "inflections": [{"form": "machine", "part_of_speech": "VB"}, {"form": "machines", "part_of_speech": "VBZ"}, {"form": "machining", "part_of_speech": "VBG"}, {"form": "machined", "part_of_speech": "VBD"}, {"form": "machined", "part_of_speech": "VBN"}]}, {"region": "US", "inflections": [{"form": "machine", "part_of_speech": "VB"}, {"form": "machines", "part_of_speech": "VBZ"}, {"form": "machining", "part_of_speech": "VBG"}, {"form": "machined", "part_of_speech": "VBD"}, {"form": "machined", "part_of_speech": "VBN"}]}], "frequency_id": "machine_vb01-fq", "oed_reference": "machine, v.", "pronunciations": [{"ipa": ["m\u0259\u02c8\u0283i\u02d0n"], "region": "British"}, {"ipa": ["m\u0259\u02c8\u0283in"], "region": "US"}], "parts_of_speech": ["VB"], "primary_sense_id": "machine_vb01-38480282"}, {"id": "machine_nn01", "band": 5, "meta": {"created": 1904, "revised": true, "updated": 2000}, "lemma": "machine", "oed_url": "https://www.oed.com/view/Entry/111850#eid38473940", "daterange": {"end": null, "start": 1545, "obsolete": false, "rangestring": "1545\u2014"}, "etymology": {"etymons": [{"word": "machine", "language": "French"}], "etymology_type": "borrowing", "etymon_language": [["European languages", "Italic", "Romance", "Italo-Western", "Gallo-Romance", "French"]], "source_language": [["European languages", "Italic", "Romance", "Italo-Western", "Gallo-Romance", "French"], ["European languages", "Italic", "Latin"], ["European languages", "Greek"]], "etymology_summary": "A borrowing from French."}, "first_use": "J. Sch\u00e4fer", "frequency": [[1750, 21], [1760, 22], [1770, 22], [1780, 23], [1790, 24], [1800, 25], [1810, 25], [1820, 26], [1830, 28], [1840, 29], [1850, 32], [1860, 35], [1870, 40], [1880, 52], [1890, 63], [1900, 74], [1910, 86], [1920, 100], [1930, 110], [1940, 110], [1950, 110], [19 ...

# %%
entry_json_lemma = json.dumps(r_lemma.json())
entry_lemma = json.loads(entry_json_lemma)

print("json \n" + entry_json_lemma)
print("entry \n" + str(entry_lemma))
# Out:
# json
# {"meta": {"total": 2, "count": 2, "offset": 0, "limit": 100, "provider": "Oxford University Press", "cite": "Oxford English Dictionary API, Oxford University Press, 0.0.0.0/oed/api/v0.2/words/?lemma=machine&offset=0&limit=100 . Accessed 15 September 2020"}, "links": {"self": "/oed/api/v0.2/words/?lemma=machine&offset=0&limit=100", "prev": null, "next": null, "first": "/oed/api/v0.2/words/?lemma=machine&offset=0&limit=100", "last": "/oed/api/v0.2/words/?lemma=machine&offset=0&limit=100"}, "data": [{"id": "machine_vb01", "band": 10, "meta": {"created": 1904, "revised": true, "updated": 2000}, "lemma": "machine", "oed_url": "https://www.oed.com/view/Entry/111851#eid38480197", "daterange": {"end": null, "start": 1450, "obsolete": false, "rangestring": "?c1450\u2014"}, "etymology": {"etymons": [{"word": "machiner", "language": "French"}, {"word": "machine", "language": "English", "target_id": "machine_nn01", "part_of_speech": "NN"}], "etymology_type": "borrowing", "etymon_language": [["European languages", "Italic", "Romance", "Italo-Western", "Gallo-Romance", "French"], ["English"]], "source_language": [["European languages", "Italic", "Romance", "Italo-Western", "Gallo-Romance", "French"], ["European languages", "Italic", "Latin"], ["English"]], "etymology_summary": "A borrowing from French."}, "first_use": "Life of St. Cuthbert", "frequency": [[1750, 0.071], [1760, 0.072], [1770, 0.076], [1780, 0.075], [1790, 0.078], [1800, 0.079], [1810, 0.079], [1820, 0.081], [1830, 0.084], [1840, 0.084], [1850, 0.096], [1860, 0.12], [1870, 0.2], [1880, 0.42], [1890, 0.69], [1900, 0.93], [1910, 1.3], [1920, 2.2], [1930, 2.7], [1940, 3.1], [1950, 3.8], [1960, 3.0], [1970, 2.9], [1980, 2.6], [1990, 2.5], [2000, 2.1], [2010, 1.9]], "sense_ids": ["machine_vb01-38480199", "machine_vb01-38480251", "machine_vb01-38480267", "machine_vb01-38480282", "machine_vb01-38480402", "machine_vb01-38480424", "machine_vb01-38480453", "machine_vb01-38480455"], "definition": "transitive. To form, make, or operate on by means of a machine; to print, engrave, cut, shape, or sew by means of a machine. Also with in, off, etc.", "main_entry": true, "inflections": [{"region": "British", "inflections": [{"form": "machine", "part_of_speech": "VB"}, {"form": "machines", "part_of_speech": "VBZ"}, {"form": "machining", "part_of_speech": "VBG"}, {"form": "machined", "part_of_speech": "VBD"}, {"form": "machined", "part_of_speech": "VBN"}]}, {"region": "US", "inflections": [{"form": "machine", "part_of_speech": "VB"}, {"form": "machines", "part_of_speech": "VBZ"}, {"form": "machining", "part_of_speech": "VBG"}, {"form": "machined", "part_of_speech": "VBD"}, {"form": "machined", "part_of_speech": "VBN"}]}], "frequency_id": "machine_vb01-fq", "oed_reference": "machine, v.", "pronunciations": [{"ipa": ["m\u0259\u02c8\u0283i\u02d0n"], "region": "British"}, {"ipa": ["m\u0259\u02c8\u0283in"], "region": "US"}], "parts_of_speech": ["VB"], "primary_sense_id": "machine_vb01-38480282"}, {"id": "machine_nn01", "band": 5, "meta": {"created": 1904, "revised": true, "updated": 2000}, "lemma": "machine", "oed_url": "https://www.oed.com/view/Entry/111850#eid38473940", "daterange": {"end": null, "start": 1545, "obsolete": false, "rangestring": "1545\u2014"}, "etymology": {"etymons": [{"word": "machine", "language": "French"}], "etymology_type": "borrowing", "etymon_language": [["European languages", "Italic", "Romance", "Italo-Western", "Gallo-Romance", "French"]], "source_language": [["European languages", "Italic", "Romance", "Italo-Western", "Gallo-Romance", "French"], ["European languages", "Italic", "Latin"], ["European languages", "Greek"]], "etymology_summary": "A borrowing from French."}, "first_use": "J. Sch\u00e4fer", "frequency": [[1750, 21], [1760, 22], [1770, 22], [1780, 23], [1790, 24], [1800, 25], [1810, 25], [1820, 26], [1830, 28], [1840, 29], [1850, 32], [1860, 35], [1870, 40], [1880, 52], [1890, 63], [1900, 74], [1910, 86], [1920, 100], [1930, 110], [1940, 110], [1950, 110], [19 ...
# entry
# {'meta': {'total': 2, 'count': 2, 'offset': 0, 'limit': 100, 'provider': 'Oxford University Press', 'cite': 'Oxford English Dictionary API, Oxford University Press, 0.0.0.0/oed/api/v0.2/words/?lemma=machine&offset=0&limit=100 . Accessed 15 September 2020'}, 'links': {'self': '/oed/api/v0.2/words/?lemma=machine&offset=0&limit=100', 'prev': None, 'next': None, 'first': '/oed/api/v0.2/words/?lemma=machine&offset=0&limit=100', 'last': '/oed/api/v0.2/words/?lemma=machine&offset=0&limit=100'}, 'data': [{'id': 'machine_vb01', 'band': 10, 'meta': {'created': 1904, 'revised': True, 'updated': 2000}, 'lemma': 'machine', 'oed_url': 'https://www.oed.com/view/Entry/111851#eid38480197', 'daterange': {'end': None, 'start': 1450, 'obsolete': False, 'rangestring': '?c1450—'}, 'etymology': {'etymons': [{'word': 'machiner', 'language': 'French'}, {'word': 'machine', 'language': 'English', 'target_id': 'machine_nn01', 'part_of_speech': 'NN'}], 'etymology_type': 'borrowing', 'etymon_language': [['European languages', 'Italic', 'Romance', 'Italo-Western', 'Gallo-Romance', 'French'], ['English']], 'source_language': [['European languages', 'Italic', 'Romance', 'Italo-Western', 'Gallo-Romance', 'French'], ['European languages', 'Italic', 'Latin'], ['English']], 'etymology_summary': 'A borrowing from French.'}, 'first_use': 'Life of St. Cuthbert', 'frequency': [[1750, 0.071], [1760, 0.072], [1770, 0.076], [1780, 0.075], [1790, 0.078], [1800, 0.079], [1810, 0.079], [1820, 0.081], [1830, 0.084], [1840, 0.084], [1850, 0.096], [1860, 0.12], [1870, 0.2], [1880, 0.42], [1890, 0.69], [1900, 0.93], [1910, 1.3], [1920, 2.2], [1930, 2.7], [1940, 3.1], [1950, 3.8], [1960, 3.0], [1970, 2.9], [1980, 2.6], [1990, 2.5], [2000, 2.1], [2010, 1.9]], 'sense_ids': ['machine_vb01-38480199', 'machine_vb01-38480251', 'machine_vb01-38480267', 'machine_vb01-38480282', 'machine_vb01-38480402', 'machine_vb01-38480424', 'machine_vb01-38480453', 'machine_vb01-38480455'], 'definition': 'transitive. To form, make, or operate on by means of a machine; to print, engrave, cut, shape, or sew by means of a machine. Also with in, off, etc.', 'main_entry': True, 'inflections': [{'region': 'British', 'inflections': [{'form': 'machine', 'part_of_speech': 'VB'}, {'form': 'machines', 'part_of_speech': 'VBZ'}, {'form': 'machining', 'part_of_speech': 'VBG'}, {'form': 'machined', 'part_of_speech': 'VBD'}, {'form': 'machined', 'part_of_speech': 'VBN'}]}, {'region': 'US', 'inflections': [{'form': 'machine', 'part_of_speech': 'VB'}, {'form': 'machines', 'part_of_speech': 'VBZ'}, {'form': 'machining', 'part_of_speech': 'VBG'}, {'form': 'machined', 'part_of_speech': 'VBD'}, {'form': 'machined', 'part_of_speech': 'VBN'}]}], 'frequency_id': 'machine_vb01-fq', 'oed_reference': 'machine, v.', 'pronunciations': [{'ipa': ['məˈʃiːn'], 'region': 'British'}, {'ipa': ['məˈʃin'], 'region': 'US'}], 'parts_of_speech': ['VB'], 'primary_sense_id': 'machine_vb01-38480282'}, {'id': 'machine_nn01', 'band': 5, 'meta': {'created': 1904, 'revised': True, 'updated': 2000}, 'lemma': 'machine', 'oed_url': 'https://www.oed.com/view/Entry/111850#eid38473940', 'daterange': {'end': None, 'start': 1545, 'obsolete': False, 'rangestring': '1545—'}, 'etymology': {'etymons': [{'word': 'machine', 'language': 'French'}], 'etymology_type': 'borrowing', 'etymon_language': [['European languages', 'Italic', 'Romance', 'Italo-Western', 'Gallo-Romance', 'French']], 'source_language': [['European languages', 'Italic', 'Romance', 'Italo-Western', 'Gallo-Romance', 'French'], ['European languages', 'Italic', 'Latin'], ['European languages', 'Greek']], 'etymology_summary': 'A borrowing from French.'}, 'first_use': 'J. Schäfer', 'frequency': [[1750, 21], [1760, 22], [1770, 22], [1780, 23], [1790, 24], [1800, 25], [1810, 25], [1820, 26], [1830, 28], [1840, 29], [1850, 32], [1860, 35], [1870, 40], [1880, 52], [1890, 63], [1900, 74], [1910, 86], [1920, 100], [1930, 110], [1940, 110], [1950, 110], [1960, 99], [1970, 93], [1980, 87], [1990, 83], [2000 ...

# %%
entry_lemma.keys()
# Out:
# dict_keys(['meta', 'links', 'data'])

# %% [markdown]
# This is the information about the query:

# %%
entry_lemma['meta']
# Out:
# {'cite': 'Oxford English Dictionary API, Oxford University Press, 0.0.0.0/oed/api/v0.2/words/?lemma=machine&offset=0&limit=100 . Accessed 15 September 2020',
#  'count': 2,
#  'limit': 100,
#  'offset': 0,
#  'provider': 'Oxford University Press',
#  'total': 2}

# %% [markdown]
# This is the content of the entry:

# %%
entry_lemma['data']
# Out:
# [{'band': 10,
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '?c1450—',
#    'start': 1450},
#   'definition': 'transitive. To form, make, or operate on by means of a machine; to print, engrave, cut, shape, or sew by means of a machine. Also with in, off, etc.',
#   'etymology': {'etymology_summary': 'A borrowing from French.',
#    'etymology_type': 'borrowing',
#    'etymon_language': [['European languages',
#      'Italic',
#      'Romance',
#      'Italo-Western',
#      'Gallo-Romance',
#      'French'],
#     ['English']],
#    'etymons': [{'language': 'French', 'word': 'machiner'},
#     {'language': 'English',
#      'part_of_speech': 'NN',
#      'target_id': 'machine_nn01',
#      'word': 'machine'}],
#    'source_language': [['European languages',
#      'Italic',
#      'Romance',
#      'Italo-Western',
#      'Gallo-Romance',
#      'French'],
#     ['European languages', 'Italic', 'Latin'],
#     ['English']]},
#   'first_use': 'Life of St. Cuthbert',
#   'frequency': [[1750, 0.071],
#    [1760, 0.072],
#    [1770, 0.076],
#    [1780, 0.075],
#    [1790, 0.078],
#    [1800, 0.079],
#    [1810, 0.079],
#    [1820, 0.081],
#    [1830, 0.084],
#    [1840, 0.084],
#    [1850, 0.096],
#    [1860, 0.12],
#    [1870, 0.2],
#    [1880, 0.42],
#    [1890, 0.69],
#    [1900, 0.93],
#    [1910, 1.3],
#    [1920, 2.2],
#    [1930, 2.7],
#    [1940, 3.1],
#    [1950, 3.8],
#    [1960, 3.0],
#    [1970, 2.9],
#    [1980, 2.6],
#    [1990, 2.5],
#    [2000, 2.1],
#    [2010, 1.9]],
#   'frequency_id': 'machine_vb01-fq',
#   'id': 'machine_vb01',
#   'inflections': [{'inflections': [{'form': 'machine', 'part_of_speech': 'VB'},
#      {'form': 'machines', 'part_of_speech': 'VBZ'},
#      {'form': 'machining', 'part_of_speech': 'VBG'},
#      {'form': 'machined', 'part_of_speech': 'VBD'},
#      {'form': 'machined', 'part_of_speech': 'VBN'}],
#     'region': 'British'},
#    {'inflections': [{'form': 'machine', 'part_of_speech': 'VB'},
#      {'form': 'machines', 'part_of_speech': 'VBZ'},
#      {'form': 'machining', 'part_of_speech': 'VBG'},
#      {'form': 'machined', 'part_of_speech': 'VBD'},
#      {'form': 'machined', 'part_of_speech': 'VBN'}],
#     'region': 'US'}],
#   'lemma': 'machine',
#   'main_entry': True,
#   'meta': {'created': 1904, 'revised': True, 'updated': 2000},
#   'oed_reference': 'machine, v.',
#   'oed_url': 'https://www.oed.com/view/Entry/111851#eid38480197',
#   'parts_of_speech': ['VB'],
#   'primary_sense_id': 'machine_vb01-38480282',
#   'pronunciations': [{'ipa': ['məˈʃiːn'], 'region': 'British'},
#    {'ipa': ['məˈʃin'], 'region': 'US'}],
#   'sense_ids': ['machine_vb01-38480199',
#    'machine_vb01-38480251',
#    'machine_vb01-38480267',
#    'machine_vb01-38480282',
#    'machine_vb01-38480402',
#    'machine_vb01-38480424',
#    'machine_vb01-38480453',
#    'machine_vb01-38480455']},
#  {'band': 5,
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '1545—',
#    'start': 1545},
#   'definition': 'A complex device, consisting of a number of interrelated parts, each having a definite function, together applying, using, or generating mechanical or (later) electrical power to perform a certain kind of work (often specified by a preceding verbal noun).',
#   'etymology': {'etymology_summary': 'A borrowing from French.',
#    'etymology_type': 'borrowing',
#    'etymon_language': [['European languages',
#      'Italic',
#      'Romance',
#      'Italo-Western',
#      'Gallo-Romance',
#      'French']],
#    'etymons': [{'language': 'French', 'word': 'machine'}],
#    'source_language': [['European languages',
#      'Italic',
#      'Romance',
#      'Italo-Western',
#      'Gallo-Romance',
#      'French'],
#     ['European languages', 'Italic', 'Latin'],
#     ['European languages', 'Greek']]},
#   'first_use': 'J. Schäfer',
#   'frequency': [[1750, 21],
#    [1760, 22],
#    [1770, 22],
#    [1780, 23],
#    [1790, 24],
#    [1800, 25],
#    [1810, 25],
#    [1820, 26],
#    [1830, 28],
#    [1840, 29],
#    [1850, 32],
#    [1860, 35],
#    [1870, 40],
#    [1880, 52],
#    [1890, 63],
#    [1900, 74],
#    [1910, 86],
#    [1920, 100],
#    [1930, 110],
#    [1940, 110],
#    [1950, 110],
#    [1960, 99],
#    [1970, 93],
#    [1980, 87],
#    [1990, 83],
#    [2000, 77],
#    [2010, 74]],
#   'frequency_id': 'machine_nn01-fq',
#   'id': 'machine_nn01',
#   'inflections': [{'inflections': [{'form': 'machine', 'part_of_speech': 'NN'},
#      {'form': 'machines', 'part_of_speech': 'NNS'}],
#     'region': 'British'},
#    {'inflections': [{'form': 'machine', 'part_of_speech': 'NN'},
#      {'form': 'machines', 'part_of_speech': 'NNS'}],
#     'region': 'US'}],
#   'lemma': 'machine',
#   'main_entry': True,
#   'meta': {'created': 1904, 'revised': True, 'updated': 2000},
#   'oed_reference': 'machine, n.',
#   'oed_url': 'https://www.oed.com/view/Entry/111850#eid38473940',
#   'parts_of_speech': ['NN'],
#   'primary_sense_id': 'machine_nn01-38475286',
#   'pronunciations': [{'ipa': ['məˈʃiːn'], 'region': 'British'},
#    {'ipa': ['məˈʃin'], 'region': 'US'}],
#   'sense_ids': ['machine_nn01-38473945',
#    'machine_nn01-38474097',
#    'machine_nn01-38474140',
#    'machine_nn01-38474233',
#    'machine_nn01-38474301',
#    'machine_nn01-38474405',
#    'machine_nn01-38474548',
#    'machine_nn01-38474607',
#    'machine_nn01-38474820',
#    'machine_nn01-38474877',
#    'machine_nn01-38474974',
#    'machine_nn01-38475013',
#    'machine_nn01-38475046',
#    'machine_nn01-38475099',
#    'machine_nn01-38475164',
#    'machine_nn01-38475286',
#    'machine_nn01-38475494',
#    'machine_nn01-38475772',
#    'machine_nn01-38475835',
#    'machine_nn01-38475923',
#    'machine_nn01-38475994',
#    'machine_nn01-38476096',
#    'machine_nn01-38476245',
#    'machine_nn01-38476316',
#    'machine_nn01-38476397',
#    'machine_nn01-38476566']}]

# %% [markdown]
# What is the entry ID for machine, n.?

# %%
url_id = "https://oed-researcher-api.oxfordlanguages.com/oed/api/v0.2/words/?lemma=machine"
r_id = requests.get(url_id, headers = {"app_id": app_id, "app_key": app_key})

# %%
entry_json_id = json.dumps(r_id.json())
entry_id = json.loads(entry_json_id)

print("json \n" + entry_json_id)
print("entry \n" + str(entry_id))
# Out:
# json
# {"meta": {"total": 2, "count": 2, "offset": 0, "limit": 100, "provider": "Oxford University Press", "cite": "Oxford English Dictionary API, Oxford University Press, 0.0.0.0/oed/api/v0.2/words/?lemma=machine&offset=0&limit=100 . Accessed 15 September 2020"}, "links": {"self": "/oed/api/v0.2/words/?lemma=machine&offset=0&limit=100", "prev": null, "next": null, "first": "/oed/api/v0.2/words/?lemma=machine&offset=0&limit=100", "last": "/oed/api/v0.2/words/?lemma=machine&offset=0&limit=100"}, "data": [{"id": "machine_vb01", "band": 10, "meta": {"created": 1904, "revised": true, "updated": 2000}, "lemma": "machine", "oed_url": "https://www.oed.com/view/Entry/111851#eid38480197", "daterange": {"end": null, "start": 1450, "obsolete": false, "rangestring": "?c1450\u2014"}, "etymology": {"etymons": [{"word": "machiner", "language": "French"}, {"word": "machine", "language": "English", "target_id": "machine_nn01", "part_of_speech": "NN"}], "etymology_type": "borrowing", "etymon_language": [["European languages", "Italic", "Romance", "Italo-Western", "Gallo-Romance", "French"], ["English"]], "source_language": [["European languages", "Italic", "Romance", "Italo-Western", "Gallo-Romance", "French"], ["European languages", "Italic", "Latin"], ["English"]], "etymology_summary": "A borrowing from French."}, "first_use": "Life of St. Cuthbert", "frequency": [[1750, 0.071], [1760, 0.072], [1770, 0.076], [1780, 0.075], [1790, 0.078], [1800, 0.079], [1810, 0.079], [1820, 0.081], [1830, 0.084], [1840, 0.084], [1850, 0.096], [1860, 0.12], [1870, 0.2], [1880, 0.42], [1890, 0.69], [1900, 0.93], [1910, 1.3], [1920, 2.2], [1930, 2.7], [1940, 3.1], [1950, 3.8], [1960, 3.0], [1970, 2.9], [1980, 2.6], [1990, 2.5], [2000, 2.1], [2010, 1.9]], "sense_ids": ["machine_vb01-38480199", "machine_vb01-38480251", "machine_vb01-38480267", "machine_vb01-38480282", "machine_vb01-38480402", "machine_vb01-38480424", "machine_vb01-38480453", "machine_vb01-38480455"], "definition": "transitive. To form, make, or operate on by means of a machine; to print, engrave, cut, shape, or sew by means of a machine. Also with in, off, etc.", "main_entry": true, "inflections": [{"region": "British", "inflections": [{"form": "machine", "part_of_speech": "VB"}, {"form": "machines", "part_of_speech": "VBZ"}, {"form": "machining", "part_of_speech": "VBG"}, {"form": "machined", "part_of_speech": "VBD"}, {"form": "machined", "part_of_speech": "VBN"}]}, {"region": "US", "inflections": [{"form": "machine", "part_of_speech": "VB"}, {"form": "machines", "part_of_speech": "VBZ"}, {"form": "machining", "part_of_speech": "VBG"}, {"form": "machined", "part_of_speech": "VBD"}, {"form": "machined", "part_of_speech": "VBN"}]}], "frequency_id": "machine_vb01-fq", "oed_reference": "machine, v.", "pronunciations": [{"ipa": ["m\u0259\u02c8\u0283i\u02d0n"], "region": "British"}, {"ipa": ["m\u0259\u02c8\u0283in"], "region": "US"}], "parts_of_speech": ["VB"], "primary_sense_id": "machine_vb01-38480282"}, {"id": "machine_nn01", "band": 5, "meta": {"created": 1904, "revised": true, "updated": 2000}, "lemma": "machine", "oed_url": "https://www.oed.com/view/Entry/111850#eid38473940", "daterange": {"end": null, "start": 1545, "obsolete": false, "rangestring": "1545\u2014"}, "etymology": {"etymons": [{"word": "machine", "language": "French"}], "etymology_type": "borrowing", "etymon_language": [["European languages", "Italic", "Romance", "Italo-Western", "Gallo-Romance", "French"]], "source_language": [["European languages", "Italic", "Romance", "Italo-Western", "Gallo-Romance", "French"], ["European languages", "Italic", "Latin"], ["European languages", "Greek"]], "etymology_summary": "A borrowing from French."}, "first_use": "J. Sch\u00e4fer", "frequency": [[1750, 21], [1760, 22], [1770, 22], [1780, 23], [1790, 24], [1800, 25], [1810, 25], [1820, 26], [1830, 28], [1840, 29], [1850, 32], [1860, 35], [1870, 40], [1880, 52], [1890, 63], [1900, 74], [1910, 86], [1920, 100], [1930, 110], [1940, 110], [1950, 110], [19 ...
# entry
# {'meta': {'total': 2, 'count': 2, 'offset': 0, 'limit': 100, 'provider': 'Oxford University Press', 'cite': 'Oxford English Dictionary API, Oxford University Press, 0.0.0.0/oed/api/v0.2/words/?lemma=machine&offset=0&limit=100 . Accessed 15 September 2020'}, 'links': {'self': '/oed/api/v0.2/words/?lemma=machine&offset=0&limit=100', 'prev': None, 'next': None, 'first': '/oed/api/v0.2/words/?lemma=machine&offset=0&limit=100', 'last': '/oed/api/v0.2/words/?lemma=machine&offset=0&limit=100'}, 'data': [{'id': 'machine_vb01', 'band': 10, 'meta': {'created': 1904, 'revised': True, 'updated': 2000}, 'lemma': 'machine', 'oed_url': 'https://www.oed.com/view/Entry/111851#eid38480197', 'daterange': {'end': None, 'start': 1450, 'obsolete': False, 'rangestring': '?c1450—'}, 'etymology': {'etymons': [{'word': 'machiner', 'language': 'French'}, {'word': 'machine', 'language': 'English', 'target_id': 'machine_nn01', 'part_of_speech': 'NN'}], 'etymology_type': 'borrowing', 'etymon_language': [['European languages', 'Italic', 'Romance', 'Italo-Western', 'Gallo-Romance', 'French'], ['English']], 'source_language': [['European languages', 'Italic', 'Romance', 'Italo-Western', 'Gallo-Romance', 'French'], ['European languages', 'Italic', 'Latin'], ['English']], 'etymology_summary': 'A borrowing from French.'}, 'first_use': 'Life of St. Cuthbert', 'frequency': [[1750, 0.071], [1760, 0.072], [1770, 0.076], [1780, 0.075], [1790, 0.078], [1800, 0.079], [1810, 0.079], [1820, 0.081], [1830, 0.084], [1840, 0.084], [1850, 0.096], [1860, 0.12], [1870, 0.2], [1880, 0.42], [1890, 0.69], [1900, 0.93], [1910, 1.3], [1920, 2.2], [1930, 2.7], [1940, 3.1], [1950, 3.8], [1960, 3.0], [1970, 2.9], [1980, 2.6], [1990, 2.5], [2000, 2.1], [2010, 1.9]], 'sense_ids': ['machine_vb01-38480199', 'machine_vb01-38480251', 'machine_vb01-38480267', 'machine_vb01-38480282', 'machine_vb01-38480402', 'machine_vb01-38480424', 'machine_vb01-38480453', 'machine_vb01-38480455'], 'definition': 'transitive. To form, make, or operate on by means of a machine; to print, engrave, cut, shape, or sew by means of a machine. Also with in, off, etc.', 'main_entry': True, 'inflections': [{'region': 'British', 'inflections': [{'form': 'machine', 'part_of_speech': 'VB'}, {'form': 'machines', 'part_of_speech': 'VBZ'}, {'form': 'machining', 'part_of_speech': 'VBG'}, {'form': 'machined', 'part_of_speech': 'VBD'}, {'form': 'machined', 'part_of_speech': 'VBN'}]}, {'region': 'US', 'inflections': [{'form': 'machine', 'part_of_speech': 'VB'}, {'form': 'machines', 'part_of_speech': 'VBZ'}, {'form': 'machining', 'part_of_speech': 'VBG'}, {'form': 'machined', 'part_of_speech': 'VBD'}, {'form': 'machined', 'part_of_speech': 'VBN'}]}], 'frequency_id': 'machine_vb01-fq', 'oed_reference': 'machine, v.', 'pronunciations': [{'ipa': ['məˈʃiːn'], 'region': 'British'}, {'ipa': ['məˈʃin'], 'region': 'US'}], 'parts_of_speech': ['VB'], 'primary_sense_id': 'machine_vb01-38480282'}, {'id': 'machine_nn01', 'band': 5, 'meta': {'created': 1904, 'revised': True, 'updated': 2000}, 'lemma': 'machine', 'oed_url': 'https://www.oed.com/view/Entry/111850#eid38473940', 'daterange': {'end': None, 'start': 1545, 'obsolete': False, 'rangestring': '1545—'}, 'etymology': {'etymons': [{'word': 'machine', 'language': 'French'}], 'etymology_type': 'borrowing', 'etymon_language': [['European languages', 'Italic', 'Romance', 'Italo-Western', 'Gallo-Romance', 'French']], 'source_language': [['European languages', 'Italic', 'Romance', 'Italo-Western', 'Gallo-Romance', 'French'], ['European languages', 'Italic', 'Latin'], ['European languages', 'Greek']], 'etymology_summary': 'A borrowing from French.'}, 'first_use': 'J. Schäfer', 'frequency': [[1750, 21], [1760, 22], [1770, 22], [1780, 23], [1790, 24], [1800, 25], [1810, 25], [1820, 26], [1830, 28], [1840, 29], [1850, 32], [1860, 35], [1870, 40], [1880, 52], [1890, 63], [1900, 74], [1910, 86], [1920, 100], [1930, 110], [1940, 110], [1950, 110], [1960, 99], [1970, 93], [1980, 87], [1990, 83], [2000 ...

# %%
len(entry_id['data'])
# Out:
# 2

# %%
for e in entry_id['data']:
    #print(e.keys())
    print(str(e['id']))
# Out:
# machine_vb01
# machine_nn01

# %% [markdown]
# There are two IDs associated to "machine". We are interested in the noun one, i.e. machine_nn01

# %%
url_senses = 'https://oed-researcher-api.oxfordlanguages.com/oed/api/v0.2/word/machine_nn01/senses/?offset=0&limit=10000'
r_senses = requests.get(url_senses, headers = {"app_id": app_id, "app_key": app_key})

# %%
#json:
entry_json_senses = json.dumps(r_senses.json())
#dictionary:
entry_senses = json.loads(entry_json_senses)

print("json \n" + entry_json_senses)
print("Python dictionary of entry \n" + str(entry_senses))
# Out:
# json
# {"meta": {"total": 26, "count": 26, "offset": 0, "limit": 10000, "provider": "Oxford University Press", "cite": "Oxford English Dictionary API, Oxford University Press, 0.0.0.0/oed/api/v0.2/word/machine_nn01/senses/?offset=0&limit=10000 . Accessed 15 September 2020"}, "links": {"self": "/oed/api/v0.2/word/machine_nn01/senses/?offset=0&limit=10000", "prev": null, "next": null, "first": "/oed/api/v0.2/word/machine_nn01/senses/?offset=0&limit=10000", "last": "/oed/api/v0.2/word/machine_nn01/senses/?offset=0&limit=10000"}, "data": [{"id": "machine_nn01-38473945", "meta": {"created": 1904, "revised": true, "updated": 2000, "sense_group": "machine_nn01-g01", "position_in_entry": 1}, "lemma": "machine", "notes": [], "oed_url": "https://www.oed.com/view/Entry/111850#eid38473945", "word_id": "machine_nn01", "daterange": {"end": null, "start": 1545, "obsolete": false, "rangestring": "1545\u2014"}, "first_use": "J. Sch\u00e4fer", "categories": {"topic": [], "region": [], "register": [["rare"]]}, "definition": "A material or immaterial structure, esp. the fabric of the world or of the universe; a construction or edifice. Now rare.", "transitivity": null, "oed_reference": "machine, n., sense I.1a", "quotation_ids": ["machine_nn01-38473950", "machine_nn01-38473961", "machine_nn01-38473973", "machine_nn01-38473981", "machine_nn01-38473999", "machine_nn01-38474007", "machine_nn01-38474047", "machine_nn01-38474058", "machine_nn01-38474068", "machine_nn01-38474079", "machine_nn01-38474089"], "part_of_speech": "NN", "main_current_sense": false, "semantic_class_ids": [["1", "111290", "118635", "119024", "120162", "120172"], ["1", "111290", "118635", "119024", "120162", "120172", "120173"]]}, {"id": "machine_nn01-38474233", "meta": {"created": 1904, "revised": true, "updated": 2000, "sense_group": "machine_nn01-g03", "position_in_entry": 4}, "lemma": "machine", "notes": [], "oed_url": "https://www.oed.com/view/Entry/111850#eid38474233", "word_id": "machine_nn01", "daterange": {"end": null, "start": 1583, "obsolete": false, "rangestring": "1583\u2014"}, "first_use": "Brian Melbancke", "categories": {"topic": [["Military", "Weaponry"]], "region": [], "register": [["historical"]]}, "definition": "A military engine or siege-tower. Cf. war machine n. (a) at  war n.1 compounds 4. Now historical.", "transitivity": null, "oed_reference": "machine, n., sense II.3", "quotation_ids": ["machine_nn01-38474243", "machine_nn01-38474252", "machine_nn01-38474260", "machine_nn01-38474268", "machine_nn01-38474281", "machine_nn01-38474290"], "part_of_speech": "NN", "main_current_sense": false, "semantic_class_ids": [["153072", "160439", "163207", "163208", "163377", "163378"]]}, {"id": "machine_nn01-38474097", "meta": {"created": 1904, "revised": true, "updated": 2000, "sense_group": "machine_nn01-g01", "position_in_entry": 2}, "lemma": "machine", "notes": [], "oed_url": "https://www.oed.com/view/Entry/111850#eid38474097", "word_id": "machine_nn01", "daterange": {"end": 1707, "start": 1595, "obsolete": true, "rangestring": "1595\u20141707"}, "first_use": "Elizabeth I", "categories": {"topic": [], "region": [], "register": []}, "definition": "spec. A scheme or plot. Obsolete.", "transitivity": null, "oed_reference": "machine, n., sense I.1b", "quotation_ids": ["machine_nn01-38474102", "machine_nn01-38474122", "machine_nn01-38474131"], "part_of_speech": "NN", "main_current_sense": false, "semantic_class_ids": [["1", "84689", "87987", "87988", "87989", "88083", "88109", "88117", "88125", "88126"]]}, {"id": "machine_nn01-38474140", "meta": {"created": 1904, "revised": true, "updated": 2000, "sense_group": "machine_nn01-g02", "position_in_entry": 3}, "lemma": "machine", "notes": [], "oed_url": "https://www.oed.com/view/Entry/111850#eid38474140", "word_id": "machine_nn01", "daterange": {"end": null, "start": 1604, "obsolete": false, "rangestring": "1604\u2014"}, "first_use": "William Shakespeare", "categories": {"topic": [["Sciences", "Medicine", "Anatomy"]], "region": [], ...
# Python dictionary of entry
# {'meta': {'total': 26, 'count': 26, 'offset': 0, 'limit': 10000, 'provider': 'Oxford University Press', 'cite': 'Oxford English Dictionary API, Oxford University Press, 0.0.0.0/oed/api/v0.2/word/machine_nn01/senses/?offset=0&limit=10000 . Accessed 15 September 2020'}, 'links': {'self': '/oed/api/v0.2/word/machine_nn01/senses/?offset=0&limit=10000', 'prev': None, 'next': None, 'first': '/oed/api/v0.2/word/machine_nn01/senses/?offset=0&limit=10000', 'last': '/oed/api/v0.2/word/machine_nn01/senses/?offset=0&limit=10000'}, 'data': [{'id': 'machine_nn01-38473945', 'meta': {'created': 1904, 'revised': True, 'updated': 2000, 'sense_group': 'machine_nn01-g01', 'position_in_entry': 1}, 'lemma': 'machine', 'notes': [], 'oed_url': 'https://www.oed.com/view/Entry/111850#eid38473945', 'word_id': 'machine_nn01', 'daterange': {'end': None, 'start': 1545, 'obsolete': False, 'rangestring': '1545—'}, 'first_use': 'J. Schäfer', 'categories': {'topic': [], 'region': [], 'register': [['rare']]}, 'definition': 'A material or immaterial structure, esp. the fabric of the world or of the universe; a construction or edifice. Now rare.', 'transitivity': None, 'oed_reference': 'machine, n., sense I.1a', 'quotation_ids': ['machine_nn01-38473950', 'machine_nn01-38473961', 'machine_nn01-38473973', 'machine_nn01-38473981', 'machine_nn01-38473999', 'machine_nn01-38474007', 'machine_nn01-38474047', 'machine_nn01-38474058', 'machine_nn01-38474068', 'machine_nn01-38474079', 'machine_nn01-38474089'], 'part_of_speech': 'NN', 'main_current_sense': False, 'semantic_class_ids': [['1', '111290', '118635', '119024', '120162', '120172'], ['1', '111290', '118635', '119024', '120162', '120172', '120173']]}, {'id': 'machine_nn01-38474233', 'meta': {'created': 1904, 'revised': True, 'updated': 2000, 'sense_group': 'machine_nn01-g03', 'position_in_entry': 4}, 'lemma': 'machine', 'notes': [], 'oed_url': 'https://www.oed.com/view/Entry/111850#eid38474233', 'word_id': 'machine_nn01', 'daterange': {'end': None, 'start': 1583, 'obsolete': False, 'rangestring': '1583—'}, 'first_use': 'Brian Melbancke', 'categories': {'topic': [['Military', 'Weaponry']], 'region': [], 'register': [['historical']]}, 'definition': 'A military engine or siege-tower. Cf. war machine n. (a) at  war n.1 compounds 4. Now historical.', 'transitivity': None, 'oed_reference': 'machine, n., sense II.3', 'quotation_ids': ['machine_nn01-38474243', 'machine_nn01-38474252', 'machine_nn01-38474260', 'machine_nn01-38474268', 'machine_nn01-38474281', 'machine_nn01-38474290'], 'part_of_speech': 'NN', 'main_current_sense': False, 'semantic_class_ids': [['153072', '160439', '163207', '163208', '163377', '163378']]}, {'id': 'machine_nn01-38474097', 'meta': {'created': 1904, 'revised': True, 'updated': 2000, 'sense_group': 'machine_nn01-g01', 'position_in_entry': 2}, 'lemma': 'machine', 'notes': [], 'oed_url': 'https://www.oed.com/view/Entry/111850#eid38474097', 'word_id': 'machine_nn01', 'daterange': {'end': 1707, 'start': 1595, 'obsolete': True, 'rangestring': '1595—1707'}, 'first_use': 'Elizabeth I', 'categories': {'topic': [], 'region': [], 'register': []}, 'definition': 'spec. A scheme or plot. Obsolete.', 'transitivity': None, 'oed_reference': 'machine, n., sense I.1b', 'quotation_ids': ['machine_nn01-38474102', 'machine_nn01-38474122', 'machine_nn01-38474131'], 'part_of_speech': 'NN', 'main_current_sense': False, 'semantic_class_ids': [['1', '84689', '87987', '87988', '87989', '88083', '88109', '88117', '88125', '88126']]}, {'id': 'machine_nn01-38474140', 'meta': {'created': 1904, 'revised': True, 'updated': 2000, 'sense_group': 'machine_nn01-g02', 'position_in_entry': 3}, 'lemma': 'machine', 'notes': [], 'oed_url': 'https://www.oed.com/view/Entry/111850#eid38474140', 'word_id': 'machine_nn01', 'daterange': {'end': None, 'start': 1604, 'obsolete': False, 'rangestring': '1604—'}, 'first_use': 'William Shakespeare', 'categories': {'topic': [['Sciences', 'Medicine', 'Anatomy']], 'region': [], 'register': []}, 'defini ...

# %%
(entry_senses['data'])
# Out:
# [{'categories': {'region': [], 'register': [['rare']], 'topic': []},
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '1545—',
#    'start': 1545},
#   'definition': 'A material or immaterial structure, esp. the fabric of the world or of the universe; a construction or edifice. Now rare.',
#   'first_use': 'J. Schäfer',
#   'id': 'machine_nn01-38473945',
#   'lemma': 'machine',
#   'main_current_sense': False,
#   'meta': {'created': 1904,
#    'position_in_entry': 1,
#    'revised': True,
#    'sense_group': 'machine_nn01-g01',
#    'updated': 2000},
#   'notes': [],
#   'oed_reference': 'machine, n., sense I.1a',
#   'oed_url': 'https://www.oed.com/view/Entry/111850#eid38473945',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['machine_nn01-38473950',
#    'machine_nn01-38473961',
#    'machine_nn01-38473973',
#    'machine_nn01-38473981',
#    'machine_nn01-38473999',
#    'machine_nn01-38474007',
#    'machine_nn01-38474047',
#    'machine_nn01-38474058',
#    'machine_nn01-38474068',
#    'machine_nn01-38474079',
#    'machine_nn01-38474089'],
#   'semantic_class_ids': [['1',
#     '111290',
#     '118635',
#     '119024',
#     '120162',
#     '120172'],
#    ['1', '111290', '118635', '119024', '120162', '120172', '120173']],
#   'transitivity': None,
#   'word_id': 'machine_nn01'},
#  {'categories': {'region': [],
#    'register': [['historical']],
#    'topic': [['Military', 'Weaponry']]},
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '1583—',
#    'start': 1583},
#   'definition': 'A military engine or siege-tower. Cf. war machine n. (a) at  war n.1 compounds 4. Now historical.',
#   'first_use': 'Brian Melbancke',
#   'id': 'machine_nn01-38474233',
#   'lemma': 'machine',
#   'main_current_sense': False,
#   'meta': {'created': 1904,
#    'position_in_entry': 4,
#    'revised': True,
#    'sense_group': 'machine_nn01-g03',
#    'updated': 2000},
#   'notes': [],
#   'oed_reference': 'machine, n., sense II.3',
#   'oed_url': 'https://www.oed.com/view/Entry/111850#eid38474233',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['machine_nn01-38474243',
#    'machine_nn01-38474252',
#    'machine_nn01-38474260',
#    'machine_nn01-38474268',
#    'machine_nn01-38474281',
#    'machine_nn01-38474290'],
#   'semantic_class_ids': [['153072',
#     '160439',
#     '163207',
#     '163208',
#     '163377',
#     '163378']],
#   'transitivity': None,
#   'word_id': 'machine_nn01'},
#  {'categories': {'region': [], 'register': [], 'topic': []},
#   'daterange': {'end': 1707,
#    'obsolete': True,
#    'rangestring': '1595—1707',
#    'start': 1595},
#   'definition': 'spec. A scheme or plot. Obsolete.',
#   'first_use': 'Elizabeth I',
#   'id': 'machine_nn01-38474097',
#   'lemma': 'machine',
#   'main_current_sense': False,
#   'meta': {'created': 1904,
#    'position_in_entry': 2,
#    'revised': True,
#    'sense_group': 'machine_nn01-g01',
#    'updated': 2000},
#   'notes': [],
#   'oed_reference': 'machine, n., sense I.1b',
#   'oed_url': 'https://www.oed.com/view/Entry/111850#eid38474097',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['machine_nn01-38474102',
#    'machine_nn01-38474122',
#    'machine_nn01-38474131'],
#   'semantic_class_ids': [['1',
#     '84689',
#     '87987',
#     '87988',
#     '87989',
#     '88083',
#     '88109',
#     '88117',
#     '88125',
#     '88126']],
#   'transitivity': None,
#   'word_id': 'machine_nn01'},
#  {'categories': {'region': [],
#    'register': [],
#    'topic': [['Sciences', 'Medicine', 'Anatomy']]},
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '1604—',
#    'start': 1604},
#   'definition': 'A living body, esp. the human body considered in general or individually. Now chiefly figurative from sense 6b (cf. sense 8b).',
#   'first_use': 'William Shakespeare',
#   'id': 'machine_nn01-38474140',
#   'lemma': 'machine',
#   'main_current_sense': False,
#   'meta': {'created': 1904,
#    'position_in_entry': 3,
#    'revised': True,
#    'sense_group': 'machine_nn01-g02',
#    'updated': 2000},
#   'notes': [],
#   'oed_reference': 'machine, n., sense I.2',
#   'oed_url': 'https://www.oed.com/view/Entry/111850#eid38474140',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['machine_nn01-38474151',
#    'machine_nn01-38474160',
#    'machine_nn01-38474169',
#    'machine_nn01-38474177',
#    'machine_nn01-38474186',
#    'machine_nn01-38474195',
#    'machine_nn01-38474203',
#    'machine_nn01-38474212',
#    'machine_nn01-38474223'],
#   'semantic_class_ids': [['1', '8835', '25507', '29189']],
#   'transitivity': None,
#   'word_id': 'machine_nn01'},
#  {'categories': {'region': [],
#    'register': [['historical'], ['poetic and literary']],
#    'topic': [['Arts', 'Performing Arts', 'Theatre']]},
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '1609—',
#    'start': 1609},
#   'definition': 'Theatre. A (usually movable) contrivance for the production of stage-effects; (in plural) stage machinery. Also figurative. Cf. god from the machine at  god n. int.phrases 4e and deus ex machina n. Now historical and poetic.',
#   'first_use': 'Ben Jonson',
#   'id': 'machine_nn01-38474301',
#   'lemma': 'machine',
#   'main_current_sense': False,
#   'meta': {'created': 1904,
#    'position_in_entry': 5,
#    'revised': True,
#    'sense_group': 'machine_nn01-g04',
#    'updated': 2000},
#   'notes': ['In early use predominantly a ‘flying’ car along with the mechanism used to lower it to the stage, often as the climax of a production.'],
#   'oed_reference': 'machine, n., sense II.4a',
#   'oed_url': 'https://www.oed.com/view/Entry/111850#eid38474301',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['machine_nn01-38474320',
#    'machine_nn01-38474329',
#    'machine_nn01-38474336',
#    'machine_nn01-38474363',
#    'machine_nn01-38474372',
#    'machine_nn01-38474380',
#    'machine_nn01-38474388',
#    'machine_nn01-38474396'],
#   'semantic_class_ids': [['153072',
#     '222360',
#     '224508',
#     '232933',
#     '232967',
#     '233050',
#     '233119',
#     '233127',
#     '233139']],
#   'transitivity': None,
#   'word_id': 'machine_nn01'},
#  {'categories': {'region': [],
#    'register': [['colloquial and slang']],
#    'topic': [['Transport', 'Nautical']]},
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '1637—',
#    'start': 1637},
#   'definition': 'A ship or other vessel. Now colloquial: a boat.',
#   'first_use': 'Thomas Heywood',
#   'id': 'machine_nn01-38474548',
#   'lemma': 'machine',
#   'main_current_sense': False,
#   'meta': {'created': 1904,
#    'position_in_entry': 7,
#    'revised': True,
#    'sense_group': 'machine_nn01-g05',
#    'updated': 2000},
#   'notes': [],
#   'oed_reference': 'machine, n., sense III.5a',
#   'oed_url': 'https://www.oed.com/view/Entry/111850#eid38474548',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['machine_nn01-38474552',
#    'machine_nn01-38474562',
#    'machine_nn01-38474572',
#    'machine_nn01-38474581',
#    'machine_nn01-38474590',
#    'machine_nn01-38474599'],
#   'semantic_class_ids': [['153072', '198379', '202986', '204466', '206654']],
#   'transitivity': None,
#   'word_id': 'machine_nn01'},
#  {'categories': {'region': [['North America', 'Canada']],
#    'register': [['archaic'], ['regional']],
#    'topic': []},
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '1648—',
#    'start': 1648},
#   'definition': 'In general use: an apparatus, device, instrument, or implement (now archaic and Canadian regional (Newfoundland)); an appliance; a vending machine. Cf. sense 6c.',
#   'first_use': 'Moderate',
#   'id': 'machine_nn01-38475164',
#   'lemma': 'machine',
#   'main_current_sense': False,
#   'meta': {'created': 1904,
#    'position_in_entry': 15,
#    'revised': True,
#    'sense_group': 'machine_nn01-g06',
#    'updated': 2000},
#   'notes': [],
#   'oed_reference': 'machine, n., sense IV.6a',
#   'oed_url': 'https://www.oed.com/view/Entry/111850#eid38475164',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['machine_nn01-208243324',
#    'machine_nn01-38475174',
#    'machine_nn01-38475182',
#    'machine_nn01-38475192',
#    'machine_nn01-38475201',
#    'machine_nn01-38475211',
#    'machine_nn01-38475223',
#    'machine_nn01-38475231',
#    'machine_nn01-38475239',
#    'machine_nn01-38475247',
#    'machine_nn01-38475258',
#    'machine_nn01-38475275'],
#   'semantic_class_ids': [['1',
#     '84689',
#     '87987',
#     '87988',
#     '87989',
#     '88083',
#     '88109',
#     '88117',
#     '88146',
#     '88147'],
#    ['153072', '208185', '211995', '211996', '212078']],
#   'transitivity': None,
#   'word_id': 'machine_nn01'},
#  {'categories': {'region': [],
#    'register': [],
#    'topic': [['Technology', 'Electrical'],
#     ['Technology', 'Engineering', 'Mechanics']]},
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '1659—',
#    'start': 1659},
#   'definition': 'A complex device, consisting of a number of interrelated parts, each having a definite function, together applying, using, or generating mechanical or (later) electrical power to perform a certain kind of work (often specified by a preceding verbal noun).',
#   'first_use': 'T. St. Serfe',
#   'id': 'machine_nn01-38475286',
#   'lemma': 'machine',
#   'main_current_sense': True,
#   'meta': {'created': 1904,
#    'position_in_entry': 16,
#    'revised': True,
#    'sense_group': 'machine_nn01-g06',
#    'updated': 2000},
#   'notes': ['In 19th- and early 20th-cent. use, the word tended to be applied to devices performing, (relatively) independently of the strength or skill of the operator, work that had formerly been done by hand. Its use has been extended to devices that perform tasks which previously required human mental activity.'],
#   'oed_reference': 'machine, n., sense IV.6b',
#   'oed_url': 'https://www.oed.com/view/Entry/111850#eid38475286',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['machine_nn01-38475290',
#    'machine_nn01-38475300',
#    'machine_nn01-38475325',
#    'machine_nn01-38475337',
#    'machine_nn01-38475346',
#    'machine_nn01-38475356',
#    'machine_nn01-38475365',
#    'machine_nn01-38475375',
#    'machine_nn01-38475383',
#    'machine_nn01-38475392',
#    'machine_nn01-38475400',
#    'machine_nn01-38475409',
#    'machine_nn01-38475420',
#    'machine_nn01-38475428',
#    'machine_nn01-38475436',
#    'machine_nn01-38475446',
#    'machine_nn01-38475454',
#    'machine_nn01-38475462',
#    'machine_nn01-38475470',
#    'machine_nn01-38475478',
#    'machine_nn01-38475486'],
#   'semantic_class_ids': [['153072', '208185', '211995', '213839', '214572']],
#   'transitivity': None,
#   'word_id': 'machine_nn01'},
#  {'categories': {'region': [], 'register': [['rare']], 'topic': []},
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '1674—',
#    'start': 1674},
#   'definition': 'In literature, etc.: a contrivance for the sake of effect; a supernatural agency, personage, or incident introduced into a narrative; the interposition of one of these. Now rare.',
#   'first_use': 'Thomas Rymer',
#   'id': 'machine_nn01-38474405',
#   'lemma': 'machine',
#   'main_current_sense': False,
#   'meta': {'created': 1904,
#    'position_in_entry': 6,
#    'revised': True,
#    'sense_group': 'machine_nn01-g04',
#    'updated': 2000},
#   'notes': [],
#   'oed_reference': 'machine, n., sense II.4b',
#   'oed_url': 'https://www.oed.com/view/Entry/111850#eid38474405',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['machine_nn01-38474409',
#    'machine_nn01-38474419',
#    'machine_nn01-38474449',
#    'machine_nn01-38474466',
#    'machine_nn01-38474507',
#    'machine_nn01-38474516',
#    'machine_nn01-38474525',
#    'machine_nn01-38474534'],
#   'semantic_class_ids': [],
#   'transitivity': None,
#   'word_id': 'machine_nn01'},
#  {'categories': {'region': [], 'register': [], 'topic': []},
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '1676—',
#    'start': 1676},
#   'definition': 'figurative in general use.',
#   'first_use': 'Thomas Guidott',
#   'id': 'machine_nn01-38475994',
#   'lemma': 'machine',
#   'main_current_sense': False,
#   'meta': {'created': 1904,
#    'position_in_entry': 21,
#    'revised': True,
#    'sense_group': 'machine_nn01-g08',
#    'updated': 2000},
#   'notes': [],
#   'oed_reference': 'machine, n., sense V.8a',
#   'oed_url': 'https://www.oed.com/view/Entry/111850#eid38475994',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['machine_nn01-38475998',
#    'machine_nn01-38476016',
#    'machine_nn01-38476026',
#    'machine_nn01-38476037',
#    'machine_nn01-38476047',
#    'machine_nn01-38476055',
#    'machine_nn01-38476065',
#    'machine_nn01-38476075',
#    'machine_nn01-38476085'],
#   'semantic_class_ids': [],
#   'transitivity': None,
#   'word_id': 'machine_nn01'},
#  {'categories': {'region': [], 'register': [], 'topic': []},
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '1676—',
#    'start': 1676},
#   'definition': 'figurative. A living being considered to move or act automatically or mechanically, rather than of its own volition; esp. a person who acts mechanically or unthinkingly, as from habit or obedience; a person who acts with mechanical precision or efficiency. Also: a system or organization of an impersonal or inflexible character.',
#   'first_use': "B. Lamy's Art of Speaking",
#   'id': 'machine_nn01-38476096',
#   'lemma': 'machine',
#   'main_current_sense': False,
#   'meta': {'created': 1904,
#    'position_in_entry': 22,
#    'revised': True,
#    'sense_group': 'machine_nn01-g08',
#    'updated': 2000},
#   'notes': [],
#   'oed_reference': 'machine, n., sense V.8b',
#   'oed_url': 'https://www.oed.com/view/Entry/111850#eid38476096',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['machine_nn01-38476101',
#    'machine_nn01-38476114',
#    'machine_nn01-38476124',
#    'machine_nn01-38476134',
#    'machine_nn01-38476147',
#    'machine_nn01-38476157',
#    'machine_nn01-38476166',
#    'machine_nn01-38476183',
#    'machine_nn01-38476192',
#    'machine_nn01-38476201',
#    'machine_nn01-38476209',
#    'machine_nn01-38476219',
#    'machine_nn01-38476228',
#    'machine_nn01-38476237'],
#   'semantic_class_ids': [['122209', '122210', '124580', '124795', '124796'],
#    ['122209',
#     '142646',
#     '143483',
#     '143639',
#     '143654',
#     '143655',
#     '143656',
#     '143657']],
#   'transitivity': None,
#   'word_id': 'machine_nn01'},
#  {'categories': {'region': [['Britain and Ireland', 'Britain', 'Scotland']],
#    'register': [['historical']],
#    'topic': []},
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '1687—',
#    'start': 1687},
#   'definition': 'A (usually wheeled) vehicle or conveyance, esp. one drawn by a horse or horses, or other draught animal or animals. Formerly esp.: a stagecoach or mail coach; (also) a brake, trap, or small carriage (chiefly Scottish). Now historical.',
#   'first_use': 'Archibald Lovell',
#   'id': 'machine_nn01-38474607',
#   'lemma': 'machine',
#   'main_current_sense': False,
#   'meta': {'created': 1904,
#    'position_in_entry': 8,
#    'revised': True,
#    'sense_group': 'machine_nn01-g05',
#    'updated': 2000},
#   'notes': [],
#   'oed_reference': 'machine, n., sense III.5b',
#   'oed_url': 'https://www.oed.com/view/Entry/111850#eid38474607',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['machine_nn01-38474614',
#    'machine_nn01-38474626',
#    'machine_nn01-38474639',
#    'machine_nn01-38474647',
#    'machine_nn01-38474659',
#    'machine_nn01-38474671',
#    'machine_nn01-38474680',
#    'machine_nn01-38474689',
#    'machine_nn01-38474700',
#    'machine_nn01-38474713',
#    'machine_nn01-38474723',
#    'machine_nn01-38474731',
#    'machine_nn01-38474742',
#    'machine_nn01-38474749',
#    'machine_nn01-38474757',
#    'machine_nn01-38474765',
#    'machine_nn01-38474776',
#    'machine_nn01-38474785',
#    'machine_nn01-38474804',
#    'machine_nn01-38474811'],
#   'semantic_class_ids': [['153072', '198379', '200757', '201351', '202575'],
#    ['153072', '198379', '200757', '201351', '201370', '202530'],
#    ['153072',
#     '198379',
#     '200757',
#     '201351',
#     '201370',
#     '202408',
#     '202418',
#     '202421']],
#   'transitivity': None,
#   'word_id': 'machine_nn01'},
#  {'categories': {'region': [],
#    'register': [],
#    'topic': [['Sciences', 'Physical Sciences'],
#     ['Technology', 'Engineering', 'Mechanics']]},
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '1704—',
#    'start': 1704},
#   'definition': 'Mechanics. Anything that transmits force or directs its application.',
#   'first_use': 'John Harris',
#   'id': 'machine_nn01-38475923',
#   'lemma': 'machine',
#   'main_current_sense': False,
#   'meta': {'created': 1904,
#    'position_in_entry': 20,
#    'revised': True,
#    'sense_group': 'machine_nn01-g07',
#    'updated': 2000},
#   'notes': ['simple, compound machine: see the first element.'],
#   'oed_reference': 'machine, n., sense IV.7',
#   'oed_url': 'https://www.oed.com/view/Entry/111850#eid38475923',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['machine_nn01-38475930',
#    'machine_nn01-38475939',
#    'machine_nn01-38475947',
#    'machine_nn01-38475955',
#    'machine_nn01-38475963',
#    'machine_nn01-38475982'],
#   'semantic_class_ids': [['153072',
#     '208185',
#     '211995',
#     '213839',
#     '213903',
#     '214198'],
#    ['1',
#     '67134',
#     '75461',
#     '75462',
#     '75463',
#     '75580',
#     '75656',
#     '75660',
#     '75661']],
#   'transitivity': None,
#   'word_id': 'machine_nn01'},
#  {'categories': {'region': [],
#    'register': [['colloquial and slang'], ['rare']],
#    'topic': [['Sciences', 'Medicine', 'Anatomy']]},
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '1749—',
#    'start': 1749},
#   'definition': 'slang. The penis; the female genitals (rare). Also: †a condom (obsolete).',
#   'first_use': 'John Cleland',
#   'id': 'machine_nn01-38476316',
#   'lemma': 'machine',
#   'main_current_sense': False,
#   'meta': {'created': 1904,
#    'position_in_entry': 24,
#    'revised': True,
#    'sense_group': 'machine_nn01-g09',
#    'updated': 2000},
#   'notes': [],
#   'oed_reference': 'machine, n., sense V.9',
#   'oed_url': 'https://www.oed.com/view/Entry/111850#eid38476316',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['machine_nn01-38476322',
#    'machine_nn01-38476331',
#    'machine_nn01-38476340',
#    'machine_nn01-38476349',
#    'machine_nn01-38476358',
#    'machine_nn01-38476372',
#    'machine_nn01-38476379',
#    'machine_nn01-38476388'],
#   'semantic_class_ids': [['1',
#     '8835',
#     '25507',
#     '28377',
#     '28378',
#     '28384',
#     '28386'],
#    ['1', '62186', '62978', '63430', '63435', '63438', '63441']],
#   'transitivity': None,
#   'word_id': 'machine_nn01'},
#  {'categories': {'region': [], 'register': [], 'topic': []},
#   'daterange': {'end': 1870,
#    'obsolete': True,
#    'rangestring': '1763—1870',
#    'start': 1763},
#   'definition': '= bathing-machine n. at  bathing n. compounds . Obsolete.',
#   'first_use': 'Ipswich Jrnl.',
#   'id': 'machine_nn01-38474820',
#   'lemma': 'machine',
#   'main_current_sense': False,
#   'meta': {'created': 1904,
#    'position_in_entry': 9,
#    'revised': True,
#    'sense_group': 'machine_nn01-g05',
#    'updated': 2000},
#   'notes': [],
#   'oed_reference': 'machine, n., sense III.5c',
#   'oed_url': 'https://www.oed.com/view/Entry/111850#eid38474820',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['machine_nn01-38474829',
#    'machine_nn01-38474837',
#    'machine_nn01-38474846',
#    'machine_nn01-38474857',
#    'machine_nn01-38474867'],
#   'semantic_class_ids': [['153072',
#     '198379',
#     '200757',
#     '201351',
#     '201370',
#     '202480',
#     '202483',
#     '202500'],
#    ['153072',
#     '222360',
#     '222361',
#     '222459',
#     '223839',
#     '223844',
#     '223848',
#     '223850']],
#   'transitivity': None,
#   'word_id': 'machine_nn01'},
#  {'categories': {'region': [['Australasia', 'Australia'],
#     ['Australasia', 'New Zealand']],
#    'register': [],
#    'topic': [['Technology', 'Engineering', 'Mechanics']]},
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '1782—',
#    'start': 1782},
#   'definition': 'Used contextually for the particular kind of machine which the speaker or writer intends, as: a sewing machine; a printing machine or mechanical printing press; a shearing-machine (Australian and New Zealand); a typewriter; a calculating machine or computer; a slot machine; a washing machine; etc. Cf. sense 6a.',
#   'first_use': 'James Woodforde',
#   'id': 'machine_nn01-38475494',
#   'lemma': 'machine',
#   'main_current_sense': False,
#   'meta': {'created': 1904,
#    'position_in_entry': 17,
#    'revised': True,
#    'sense_group': 'machine_nn01-g06',
#    'updated': 2000},
#   'notes': [],
#   'oed_reference': 'machine, n., sense IV.6c',
#   'oed_url': 'https://www.oed.com/view/Entry/111850#eid38475494',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['machine_nn01-38475502',
#    'machine_nn01-38475513',
#    'machine_nn01-38475521',
#    'machine_nn01-38475529',
#    'machine_nn01-38475550',
#    'machine_nn01-38475567',
#    'machine_nn01-38475576',
#    'machine_nn01-38475608',
#    'machine_nn01-38475618',
#    'machine_nn01-38475626',
#    'machine_nn01-38475635',
#    'machine_nn01-38475654',
#    'machine_nn01-38475662',
#    'machine_nn01-38475672',
#    'machine_nn01-38475691',
#    'machine_nn01-295454392',
#    'machine_nn01-38475706',
#    'machine_nn01-38475715',
#    'machine_nn01-38475740',
#    'machine_nn01-38475748',
#    'machine_nn01-38475756',
#    'machine_nn01-38475764'],
#   'semantic_class_ids': [['153072',
#     '208185',
#     '211995',
#     '213839',
#     '214572',
#     '214574']],
#   'transitivity': None,
#   'word_id': 'machine_nn01'},
#  {'categories': {'region': [], 'register': [['historical']], 'topic': []},
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '1823—',
#    'start': 1823},
#   'definition': 'A bicycle or tricycle; a motorcycle. Formerly also: a dandy-horse or velocipede (now historical).',
#   'first_use': 'John Badcock',
#   'id': 'machine_nn01-38474877',
#   'lemma': 'machine',
#   'main_current_sense': False,
#   'meta': {'created': 1904,
#    'position_in_entry': 10,
#    'revised': True,
#    'sense_group': 'machine_nn01-g05',
#    'updated': 2000},
#   'notes': [],
#   'oed_reference': 'machine, n., sense III.5d',
#   'oed_url': 'https://www.oed.com/view/Entry/111850#eid38474877',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['machine_nn01-38474891',
#    'machine_nn01-38474899',
#    'machine_nn01-38474907',
#    'machine_nn01-38474925',
#    'machine_nn01-38474935',
#    'machine_nn01-38474943',
#    'machine_nn01-38474950',
#    'machine_nn01-38474958',
#    'machine_nn01-38474966'],
#   'semantic_class_ids': [['153072',
#     '198379',
#     '200757',
#     '201351',
#     '201370',
#     '201563',
#     '201573',
#     '201575']],
#   'transitivity': None,
#   'word_id': 'machine_nn01'},
#  {'categories': {'region': [['North America', 'United States']],
#    'register': [['colloquial and slang']],
#    'topic': []},
#   'daterange': {'end': 1890,
#    'obsolete': True,
#    'rangestring': '1848—90',
#    'start': 1848},
#   'definition': 'U.S. colloquial. A fire engine. Obsolete.',
#   'first_use': 'N.Y. Herald',
#   'id': 'machine_nn01-38474974',
#   'lemma': 'machine',
#   'main_current_sense': False,
#   'meta': {'created': 1904,
#    'position_in_entry': 11,
#    'revised': True,
#    'sense_group': 'machine_nn01-g05',
#    'updated': 2000},
#   'notes': [],
#   'oed_reference': 'machine, n., sense III.5e',
#   'oed_url': 'https://www.oed.com/view/Entry/111850#eid38474974',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['machine_nn01-1038760531',
#    'machine_nn01-38474989',
#    'machine_nn01-38475006'],
#   'semantic_class_ids': [['1',
#     '67134',
#     '71763',
#     '71864',
#     '72718',
#     '72764',
#     '72775',
#     '72778',
#     '72790',
#     '72805']],
#   'transitivity': None,
#   'word_id': 'machine_nn01'},
#  {'categories': {'region': [['North America', 'United States']],
#    'register': [],
#    'topic': [['Politics']]},
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '1860—',
#    'start': 1860},
#   'definition': 'Originally U.S. The controlling organization of a political party or similar body; any organization or group displaying impressive or ruthless efficiency.',
#   'first_use': 'A. Burlingame',
#   'id': 'machine_nn01-38476397',
#   'lemma': 'machine',
#   'main_current_sense': False,
#   'meta': {'created': 1904,
#    'position_in_entry': 25,
#    'revised': True,
#    'sense_group': 'machine_nn01-g10',
#    'updated': 2000},
#   'notes': ['party, propaganda, war machine: see the first element.'],
#   'oed_reference': 'machine, n., sense V.10',
#   'oed_url': 'https://www.oed.com/view/Entry/111850#eid38476397',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['machine_nn01-38476417',
#    'machine_nn01-38476449',
#    'machine_nn01-38476466',
#    'machine_nn01-38476493',
#    'machine_nn01-38476501',
#    'machine_nn01-38476509',
#    'machine_nn01-38476542',
#    'machine_nn01-38476550',
#    'machine_nn01-38476558'],
#   'semantic_class_ids': [['153072',
#     '165531',
#     '166197',
#     '168151',
#     '168217',
#     '168326',
#     '168344']],
#   'transitivity': None,
#   'word_id': 'machine_nn01'},
#  {'categories': {'region': [], 'register': [], 'topic': []},
#   'daterange': {'end': 1883,
#    'obsolete': True,
#    'rangestring': '1883',
#    'start': 1883},
#   'definition': 'A box or case in which fresh fish are sold wholesale. Cf. trunk n. 8b. Obsolete.',
#   'first_use': 'S. Plimsoll',
#   'id': 'machine_nn01-38475013',
#   'lemma': 'machine',
#   'main_current_sense': False,
#   'meta': {'created': 1904,
#    'position_in_entry': 12,
#    'revised': True,
#    'sense_group': 'machine_nn01-g05',
#    'updated': 2000},
#   'notes': ['Probably extended from sense 6.'],
#   'oed_reference': 'machine, n., sense III.5f',
#   'oed_url': 'https://www.oed.com/view/Entry/111850#eid38475013',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['machine_nn01-38475026', 'machine_nn01-38475036'],
#   'semantic_class_ids': [['1',
#     '45969',
#     '45970',
#     '46185',
#     '46320',
#     '46337',
#     '46338',
#     '46370',
#     '46371']],
#   'transitivity': None,
#   'word_id': 'machine_nn01'},
#  {'categories': {'region': [['Australasia', 'Australia'],
#     ['Australasia', 'New Zealand']],
#    'register': [['colloquial and slang']],
#    'topic': [['Sport and Leisure', 'Games', 'Gambling']]},
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '1891—',
#    'start': 1891},
#   'definition': 'Australian and New Zealand colloquial. A totalizator.',
#   'first_use': 'G. P. Williams',
#   'id': 'machine_nn01-38475772',
#   'lemma': 'machine',
#   'main_current_sense': False,
#   'meta': {'created': 1904,
#    'position_in_entry': 18,
#    'revised': True,
#    'sense_group': 'machine_nn01-g06',
#    'updated': 2000},
#   'notes': [],
#   'oed_reference': 'machine, n., sense IV.6d',
#   'oed_url': 'https://www.oed.com/view/Entry/111850#eid38475772',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['machine_nn01-38475778',
#    'machine_nn01-38475800',
#    'machine_nn01-38475808',
#    'machine_nn01-38475817',
#    'machine_nn01-38475826'],
#   'semantic_class_ids': [['153072',
#     '222360',
#     '222361',
#     '222459',
#     '223668',
#     '223702',
#     '223744',
#     '223746']],
#   'transitivity': None,
#   'word_id': 'machine_nn01'},
#  {'categories': {'region': [],
#    'register': [],
#    'topic': [['Transport', 'Aviation']]},
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '1896—',
#    'start': 1896},
#   'definition': 'An aircraft or airship. Cf. sense 6b.',
#   'first_use': 'H. S. Maxim',
#   'id': 'machine_nn01-38475046',
#   'lemma': 'machine',
#   'main_current_sense': False,
#   'meta': {'created': 1904,
#    'position_in_entry': 13,
#    'revised': True,
#    'sense_group': 'machine_nn01-g05',
#    'updated': 2000},
#   'notes': [],
#   'oed_reference': 'machine, n., sense III.5g',
#   'oed_url': 'https://www.oed.com/view/Entry/111850#eid38475046',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['machine_nn01-38475059',
#    'machine_nn01-38475067',
#    'machine_nn01-38475075',
#    'machine_nn01-38475083',
#    'machine_nn01-38475091'],
#   'semantic_class_ids': [['153072',
#     '198379',
#     '206909',
#     '207619',
#     '208130',
#     '208136']],
#   'transitivity': None,
#   'word_id': 'machine_nn01'},
#  {'categories': {'region': [['North America', 'United States']],
#    'register': [],
#    'topic': [['Transport', 'Motoring']]},
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '1901—',
#    'start': 1901},
#   'definition': 'Originally and chiefly U.S. A motor vehicle, esp. a car.',
#   'first_use': "McClure's Magazine",
#   'id': 'machine_nn01-38475099',
#   'lemma': 'machine',
#   'main_current_sense': False,
#   'meta': {'created': 1904,
#    'position_in_entry': 14,
#    'revised': True,
#    'sense_group': 'machine_nn01-g05',
#    'updated': 2000},
#   'notes': [],
#   'oed_reference': 'machine, n., sense III.5h',
#   'oed_url': 'https://www.oed.com/view/Entry/111850#eid38475099',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['machine_nn01-38475104',
#    'machine_nn01-38475120',
#    'machine_nn01-38475136',
#    'machine_nn01-38475144',
#    'machine_nn01-38475153'],
#   'semantic_class_ids': [['153072',
#     '198379',
#     '200757',
#     '201351',
#     '201370',
#     '201885',
#     '202077',
#     '202100']],
#   'transitivity': None,
#   'word_id': 'machine_nn01'},
#  {'categories': {'region': [],
#    'register': [],
#    'topic': [['Arts', 'Visual Arts', 'Painting and Drawing', 'Painting']]},
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '1926—',
#    'start': 1926},
#   'definition': 'Painting. A painting of large size, esp. one whose subject matter and composition are complicated, contrived, or exaggerated.',
#   'first_use': 'Roger Fry',
#   'id': 'machine_nn01-38476566',
#   'lemma': 'machine',
#   'main_current_sense': False,
#   'meta': {'created': 1976,
#    'position_in_entry': 26,
#    'revised': True,
#    'sense_group': 'machine_nn01-g11',
#    'updated': 2000},
#   'notes': [],
#   'oed_reference': 'machine, n., sense V.11',
#   'oed_url': 'https://www.oed.com/view/Entry/111850#eid38476566',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['machine_nn01-38476571',
#    'machine_nn01-38476579',
#    'machine_nn01-38476588',
#    'machine_nn01-38476597'],
#   'semantic_class_ids': [['153072',
#     '222360',
#     '224508',
#     '227402',
#     '227682',
#     '227729',
#     '228006',
#     '228009',
#     '228011']],
#   'transitivity': None,
#   'word_id': 'machine_nn01'},
#  {'categories': {'region': [], 'register': [], 'topic': []},
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '1927—',
#    'start': 1927},
#   'definition': 'figurative.machine for living (in): a house or other habitation considered as a functional entity. Also in imitative phrases.',
#   'first_use': "‘Le Corbusier’'s Towards New Archit.",
#   'id': 'machine_nn01-38476245',
#   'lemma': 'machine for living',
#   'main_current_sense': False,
#   'meta': {'created': 1976,
#    'position_in_entry': 23,
#    'revised': True,
#    'sense_group': 'machine_nn01-g08',
#    'updated': 2000},
#   'notes': [],
#   'oed_reference': 'machine, n., sense V.8c',
#   'oed_url': 'https://www.oed.com/view/Entry/111850#eid38476245',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['machine_nn01-38476264',
#    'machine_nn01-38476281',
#    'machine_nn01-38476289',
#    'machine_nn01-38476297',
#    'machine_nn01-38476305'],
#   'semantic_class_ids': [['153072',
#     '157909',
#     '158520',
#     '158897',
#     '158994',
#     '158995',
#     '159066']],
#   'transitivity': None,
#   'word_id': 'machine_nn01'},
#  {'categories': {'region': [],
#    'register': [],
#    'topic': [['Sciences', 'Mathematics'], ['Technology', 'Computing']]},
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '1936—',
#    'start': 1936},
#   'definition': 'A conceptual, abstract, or theoretical mechanism or device; spec. a model or a mathematical abstraction of an existing or hypothetical computer. Cf. Turing machine n.',
#   'first_use': 'Alan Turing',
#   'id': 'machine_nn01-38475835',
#   'lemma': 'machine',
#   'main_current_sense': False,
#   'meta': {'created': 2000,
#    'position_in_entry': 19,
#    'revised': True,
#    'sense_group': 'machine_nn01-g06',
#    'updated': None},
#   'notes': [],
#   'oed_reference': 'machine, n., sense IV.6e',
#   'oed_url': 'https://www.oed.com/view/Entry/111850#eid38475835',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['machine_nn01-38475852',
#    'machine_nn01-38475869',
#    'machine_nn01-38475889',
#    'machine_nn01-38475915'],
#   'semantic_class_ids': [['153072',
#     '116218',
#     '116219',
#     '116319',
#     '116331',
#     '116332']],
#   'transitivity': None,
#   'word_id': 'machine_nn01'}]

# %% [markdown]
# How many senses?

# %%
len(entry_senses['data'])
# Out:
# 26

# %% [markdown]
# First sense:

# %%
entry_senses['data'][0]
# Out:
# {'categories': {'region': [], 'register': [['rare']], 'topic': []},
#  'daterange': {'end': None,
#   'obsolete': False,
#   'rangestring': '1545—',
#   'start': 1545},
#  'definition': 'A material or immaterial structure, esp. the fabric of the world or of the universe; a construction or edifice. Now rare.',
#  'first_use': 'J. Schäfer',
#  'id': 'machine_nn01-38473945',
#  'lemma': 'machine',
#  'main_current_sense': False,
#  'meta': {'created': 1904,
#   'position_in_entry': 1,
#   'revised': True,
#   'sense_group': 'machine_nn01-g01',
#   'updated': 2000},
#  'notes': [],
#  'oed_reference': 'machine, n., sense I.1a',
#  'oed_url': 'https://www.oed.com/view/Entry/111850#eid38473945',
#  'part_of_speech': 'NN',
#  'quotation_ids': ['machine_nn01-38473950',
#   'machine_nn01-38473961',
#   'machine_nn01-38473973',
#   'machine_nn01-38473981',
#   'machine_nn01-38473999',
#   'machine_nn01-38474007',
#   'machine_nn01-38474047',
#   'machine_nn01-38474058',
#   'machine_nn01-38474068',
#   'machine_nn01-38474079',
#   'machine_nn01-38474089'],
#  'semantic_class_ids': [['1',
#    '111290',
#    '118635',
#    '119024',
#    '120162',
#    '120172'],
#   ['1', '111290', '118635', '119024', '120162', '120172', '120173']],
#  'transitivity': None,
#  'word_id': 'machine_nn01'}

# %%
entry_senses['data'][0]['definition']
# Out:
# 'A material or immaterial structure, esp. the fabric of the world or of the universe; a construction or edifice. Now rare.'

# %% [markdown]
# All definitions:

# %%
for e in entry_senses['data']:
    print(e['definition'])
# Out:
# A material or immaterial structure, esp. the fabric of the world or of the universe; a construction or edifice. Now rare.
# A military engine or siege-tower. Cf. war machine n. (a) at  war n.1 compounds 4. Now historical.
# spec. A scheme or plot. Obsolete.
# A living body, esp. the human body considered in general or individually. Now chiefly figurative from sense 6b (cf. sense 8b).
# Theatre. A (usually movable) contrivance for the production of stage-effects; (in plural) stage machinery. Also figurative. Cf. god from the machine at  god n. int.phrases 4e and deus ex machina n. Now historical and poetic.
# A ship or other vessel. Now colloquial: a boat.
# In general use: an apparatus, device, instrument, or implement (now archaic and Canadian regional (Newfoundland)); an appliance; a vending machine. Cf. sense 6c.
# A complex device, consisting of a number of interrelated parts, each having a definite function, together applying, using, or generating mechanical or (later) electrical power to perform a certain kind of work (often specified by a preceding verbal noun).
# In literature, etc.: a contrivance for the sake of effect; a supernatural agency, personage, or incident introduced into a narrative; the interposition of one of these. Now rare.
# figurative in general use.
# figurative. A living being considered to move or act automatically or mechanically, rather than of its own volition; esp. a person who acts mechanically or unthinkingly, as from habit or obedience; a person who acts with mechanical precision or efficiency. Also: a system or organization of an impersonal or inflexible character.
# A (usually wheeled) vehicle or conveyance, esp. one drawn by a horse or horses, or other draught animal or animals. Formerly esp.: a stagecoach or mail coach; (also) a brake, trap, or small carriage (chiefly Scottish). Now historical.
# Mechanics. Anything that transmits force or directs its application.
# slang. The penis; the female genitals (rare). Also: †a condom (obsolete).
# = bathing-machine n. at  bathing n. compounds . Obsolete.
# Used contextually for the particular kind of machine which the speaker or writer intends, as: a sewing machine; a printing machine or mechanical printing press; a shearing-machine (Australian and New Zealand); a typewriter; a calculating machine or computer; a slot machine; a washing machine; etc. Cf. sense 6a.
# A bicycle or tricycle; a motorcycle. Formerly also: a dandy-horse or velocipede (now historical).
# U.S. colloquial. A fire engine. Obsolete.
# Originally U.S. The controlling organization of a political party or similar body; any organization or group displaying impressive or ruthless efficiency.
# A box or case in which fresh fish are sold wholesale. Cf. trunk n. 8b. Obsolete.
# Australian and New Zealand colloquial. A totalizator.
# An aircraft or airship. Cf. sense 6b.
# Originally and chiefly U.S. A motor vehicle, esp. a car.
# Painting. A painting of large size, esp. one whose subject matter and composition are complicated, contrived, or exaggerated.
# figurative.machine for living (in): a house or other habitation considered as a functional entity. Also in imitative phrases.
# A conceptual, abstract, or theoretical mechanism or device; spec. a model or a mathematical abstraction of an existing or hypothetical computer. Cf. Turing machine n.

# %% [markdown]
# All definitions that were current in 1789:

# %%
count = 0
for e in entry_senses['data']:
    if e['daterange']['end'] is None or int(e['daterange']['end'])>= 1789:
        count += 1
        print(e['definition'])
print(str(count))
# Out:
# A material or immaterial structure, esp. the fabric of the world or of the universe; a construction or edifice. Now rare.
# A military engine or siege-tower. Cf. war machine n. (a) at  war n.1 compounds 4. Now historical.
# A living body, esp. the human body considered in general or individually. Now chiefly figurative from sense 6b (cf. sense 8b).
# Theatre. A (usually movable) contrivance for the production of stage-effects; (in plural) stage machinery. Also figurative. Cf. god from the machine at  god n. int.phrases 4e and deus ex machina n. Now historical and poetic.
# A ship or other vessel. Now colloquial: a boat.
# In general use: an apparatus, device, instrument, or implement (now archaic and Canadian regional (Newfoundland)); an appliance; a vending machine. Cf. sense 6c.
# A complex device, consisting of a number of interrelated parts, each having a definite function, together applying, using, or generating mechanical or (later) electrical power to perform a certain kind of work (often specified by a preceding verbal noun).
# In literature, etc.: a contrivance for the sake of effect; a supernatural agency, personage, or incident introduced into a narrative; the interposition of one of these. Now rare.
# figurative in general use.
# figurative. A living being considered to move or act automatically or mechanically, rather than of its own volition; esp. a person who acts mechanically or unthinkingly, as from habit or obedience; a person who acts with mechanical precision or efficiency. Also: a system or organization of an impersonal or inflexible character.
# A (usually wheeled) vehicle or conveyance, esp. one drawn by a horse or horses, or other draught animal or animals. Formerly esp.: a stagecoach or mail coach; (also) a brake, trap, or small carriage (chiefly Scottish). Now historical.
# Mechanics. Anything that transmits force or directs its application.
# slang. The penis; the female genitals (rare). Also: †a condom (obsolete).
# = bathing-machine n. at  bathing n. compounds . Obsolete.
# Used contextually for the particular kind of machine which the speaker or writer intends, as: a sewing machine; a printing machine or mechanical printing press; a shearing-machine (Australian and New Zealand); a typewriter; a calculating machine or computer; a slot machine; a washing machine; etc. Cf. sense 6a.
# A bicycle or tricycle; a motorcycle. Formerly also: a dandy-horse or velocipede (now historical).
# U.S. colloquial. A fire engine. Obsolete.
# Originally U.S. The controlling organization of a political party or similar body; any organization or group displaying impressive or ruthless efficiency.
# A box or case in which fresh fish are sold wholesale. Cf. trunk n. 8b. Obsolete.
# Australian and New Zealand colloquial. A totalizator.
# An aircraft or airship. Cf. sense 6b.
# Originally and chiefly U.S. A motor vehicle, esp. a car.
# Painting. A painting of large size, esp. one whose subject matter and composition are complicated, contrived, or exaggerated.
# figurative.machine for living (in): a house or other habitation considered as a functional entity. Also in imitative phrases.
# A conceptual, abstract, or theoretical mechanism or device; spec. a model or a mathematical abstraction of an existing or hypothetical computer. Cf. Turing machine n.
# 25

# %% [markdown]
# With semantic classes:

# %%
for e in entry_senses['data']:
    if e['daterange']['end'] is None or int(e['daterange']['end'])>= 1789:
        print(e['definition'])
        print(e['semantic_class_ids'])
# Out:
# A material or immaterial structure, esp. the fabric of the world or of the universe; a construction or edifice. Now rare.
# [['1', '111290', '118635', '119024', '120162', '120172'], ['1', '111290', '118635', '119024', '120162', '120172', '120173']]
# A military engine or siege-tower. Cf. war machine n. (a) at  war n.1 compounds 4. Now historical.
# [['153072', '160439', '163207', '163208', '163377', '163378']]
# A living body, esp. the human body considered in general or individually. Now chiefly figurative from sense 6b (cf. sense 8b).
# [['1', '8835', '25507', '29189']]
# Theatre. A (usually movable) contrivance for the production of stage-effects; (in plural) stage machinery. Also figurative. Cf. god from the machine at  god n. int.phrases 4e and deus ex machina n. Now historical and poetic.
# [['153072', '222360', '224508', '232933', '232967', '233050', '233119', '233127', '233139']]
# A ship or other vessel. Now colloquial: a boat.
# [['153072', '198379', '202986', '204466', '206654']]
# In general use: an apparatus, device, instrument, or implement (now archaic and Canadian regional (Newfoundland)); an appliance; a vending machine. Cf. sense 6c.
# [['1', '84689', '87987', '87988', '87989', '88083', '88109', '88117', '88146', '88147'], ['153072', '208185', '211995', '211996', '212078']]
# A complex device, consisting of a number of interrelated parts, each having a definite function, together applying, using, or generating mechanical or (later) electrical power to perform a certain kind of work (often specified by a preceding verbal noun).
# [['153072', '208185', '211995', '213839', '214572']]
# In literature, etc.: a contrivance for the sake of effect; a supernatural agency, personage, or incident introduced into a narrative; the interposition of one of these. Now rare.
# []
# figurative in general use.
# []
# figurative. A living being considered to move or act automatically or mechanically, rather than of its own volition; esp. a person who acts mechanically or unthinkingly, as from habit or obedience; a person who acts with mechanical precision or efficiency. Also: a system or organization of an impersonal or inflexible character.
# [['122209', '122210', '124580', '124795', '124796'], ['122209', '142646', '143483', '143639', '143654', '143655', '143656', '143657']]
# A (usually wheeled) vehicle or conveyance, esp. one drawn by a horse or horses, or other draught animal or animals. Formerly esp.: a stagecoach or mail coach; (also) a brake, trap, or small carriage (chiefly Scottish). Now historical.
# [['153072', '198379', '200757', '201351', '202575'], ['153072', '198379', '200757', '201351', '201370', '202530'], ['153072', '198379', '200757', '201351', '201370', '202408', '202418', '202421']]
# Mechanics. Anything that transmits force or directs its application.
# [['153072', '208185', '211995', '213839', '213903', '214198'], ['1', '67134', '75461', '75462', '75463', '75580', '75656', '75660', '75661']]
# slang. The penis; the female genitals (rare). Also: †a condom (obsolete).
# [['1', '8835', '25507', '28377', '28378', '28384', '28386'], ['1', '62186', '62978', '63430', '63435', '63438', '63441']]
# = bathing-machine n. at  bathing n. compounds . Obsolete.
# [['153072', '198379', '200757', '201351', '201370', '202480', '202483', '202500'], ['153072', '222360', '222361', '222459', '223839', '223844', '223848', '223850']]
# Used contextually for the particular kind of machine which the speaker or writer intends, as: a sewing machine; a printing machine or mechanical printing press; a shearing-machine (Australian and New Zealand); a typewriter; a calculating machine or computer; a slot machine; a washing machine; etc. Cf. sense 6a.
# [['153072', '208185', '211995', '213839', '214572', '214574']]
# A bicycle or tricycle; a motorcycle. Formerly also: a dandy-horse or velocipede (now historical).
# [['153072', '198379', '200757', '201351', '201370', '201563', '201573', '201575']]
# U.S. colloquial. A fire engine. Obsolete.
# [['1', '67134', '71763', '71864', '72718', '72764', '72775', '72778', '72790', '72805']]
# Originally U.S. The controlling organization of a political party or similar body; any organization or group displaying impressive or ruthless efficiency.
# [['153072', '165531', '166197', '168151', '168217', '168326', '168344']]
# A box or case in which fresh fish are sold wholesale. Cf. trunk n. 8b. Obsolete.
# [['1', '45969', '45970', '46185', '46320', '46337', '46338', '46370', '46371']]
# Australian and New Zealand colloquial. A totalizator.
# [['153072', '222360', '222361', '222459', '223668', '223702', '223744', '223746']]
# An aircraft or airship. Cf. sense 6b.
# [['153072', '198379', '206909', '207619', '208130', '208136']]
# Originally and chiefly U.S. A motor vehicle, esp. a car.
# [['153072', '198379', '200757', '201351', '201370', '201885', '202077', '202100']]
# Painting. A painting of large size, esp. one whose subject matter and composition are complicated, contrived, or exaggerated.
# [['153072', '222360', '224508', '227402', '227682', '227729', '228006', '228009', '228011']]
# figurative.machine for living (in): a house or other habitation considered as a functional entity. Also in imitative phrases.
# [['153072', '157909', '158520', '158897', '158994', '158995', '159066']]
# A conceptual, abstract, or theoretical mechanism or device; spec. a model or a mathematical abstraction of an existing or hypothetical computer. Cf. Turing machine n.
# [['153072', '116218', '116219', '116319', '116331', '116332']]

# %% [markdown]
# Let us take the first sense, and its semantic classes:

# %%
e_0 = entry_senses['data'][0]
definition_0 = e_0['definition']
semantic_class_ids = e_0['semantic_class_ids']

# %%
definition_0
# Out:
# 'A material or immaterial structure, esp. the fabric of the world or of the universe; a construction or edifice. Now rare.'

# %%
semantic_class_ids
# Out:
# [['1', '111290', '118635', '119024', '120162', '120172'],
#  ['1', '111290', '118635', '119024', '120162', '120172', '120173']]

# %%
len(semantic_class_ids)
# Out:
# 2

# %% [markdown]
# What is the semantic class?

# %%
url_sem = "https://oed-researcher-api.oxfordlanguages.com/oed/api/v0.2/semanticclass/" + "1"
r_sem = requests.get(url_sem, headers = {"app_id": app_id, "app_key": app_key})
entry_json_sem = json.dumps(r_sem.json())
entry_sem = json.loads(entry_json_sem)

# %%
entry_sem['data']['label']
# Out:
# 'the world'

# %% [markdown]
# Inspect all semantic classes of first sense:

# %% [markdown]
# there are two sets, this is the first one:

# %%
for sem_id in semantic_class_ids[0]:
    print(sem_id)
    url_sem = "https://oed-researcher-api.oxfordlanguages.com/oed/api/v0.2/semanticclass/" + str(sem_id)
    r_sem = requests.get(url_sem, headers = {"app_id": app_id, "app_key": app_key})
    entry_json_sem = json.dumps(r_sem.json())
    entry_sem = json.loads(entry_json_sem)
    #print(str(entry_sem))
    print(entry_sem['data']['label'])
# Out:
# 1
# the world
# 111290
# relative properties
# 118635
# wholeness
# 119024
# mutual relation of parts to whole
# 120162
# None
# 120172
# a structure

# %% [markdown]
# These are sorted from the most general to the most specific, i.e. down the thesaurus hierarchy.

# %% [markdown]
# This is the second one:

# %%
for sem_id in semantic_class_ids[1]:
    print(sem_id)
    url_sem = "https://oed-researcher-api.oxfordlanguages.com/oed/api/v0.2/semanticclass/" + str(sem_id)
    r_sem = requests.get(url_sem, headers = {"app_id": app_id, "app_key": app_key})
    entry_json_sem = json.dumps(r_sem.json())
    entry_sem = json.loads(entry_json_sem)
    #print(str(entry_sem))
    print(entry_sem['data']['label'])
# Out:
# 1
# the world
# 111290
# relative properties
# 118635
# wholeness
# 119024
# mutual relation of parts to whole
# 120162
# None
# 120172
# a structure
# 120173
# immaterial

# %% [markdown]
# Include both sets:

# %%
for i in range(len(semantic_class_ids)):
    print(str(i))
    for sem_id in semantic_class_ids[i]:
        print(sem_id)
        url_sem = "https://oed-researcher-api.oxfordlanguages.com/oed/api/v0.2/semanticclass/" + str(sem_id)
        r_sem = requests.get(url_sem, headers = {"app_id": app_id, "app_key": app_key})
        entry_json_sem = json.dumps(r_sem.json())
        entry_sem = json.loads(entry_json_sem)
        #print(str(entry_sem))
        print(entry_sem['data']['label'])
# Out:
# 0
# 1
# the world
# 111290
# relative properties
# 118635
# wholeness
# 119024
# mutual relation of parts to whole
# 120162
# None
# 120172
# a structure
# 1
# 1
# the world
# 111290
# relative properties
# 118635
# wholeness
# 119024
# mutual relation of parts to whole
# 120162
# None
# 120172
# a structure
# 120173
# immaterial

# %% [markdown]
# Let us look at the senses associated to a semantic class, e.g. 120172:

# %%
url_sensessem = "https://oed-researcher-api.oxfordlanguages.com/oed/api/v0.2/semanticclass/" + str(120172) + "/senses/"
r_sensessem = requests.get(url_sensessem, headers = {"app_id": app_id, "app_key": app_key})
entry_json_sensessem = json.dumps(r_sensessem.json())
entry_sensessem = json.loads(entry_json_sensessem)

# %%
entry_sensessem['data']
# Out:
# [{'categories': {'region': [], 'register': [], 'topic': []},
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '1800—',
#    'start': 1800},
#   'definition': 'concrete. A structure or combination of things arranged in a particular way or for any purpose; hence loosely, like affair, concern, production.',
#   'first_use': 'William Herschel',
#   'id': 'arrangement_nn01-39073466',
#   'lemma': 'arrangement',
#   'main_current_sense': False,
#   'meta': {'created': 1885,
#    'position_in_entry': 4,
#    'revised': False,
#    'sense_group': 'arrangement_nn01-g04',
#    'updated': None},
#   'notes': [],
#   'oed_reference': 'arrangement, n., sense 4',
#   'oed_url': 'https://www.oed.com/view/Entry/10968#eid39073466',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['arrangement_nn01-39073473',
#    'arrangement_nn01-39073483',
#    'arrangement_nn01-39073492'],
#   'semantic_class_ids': [['1',
#     '97163',
#     '101153',
#     '104182',
#     '104802',
#     '104811'],
#    ['1', '111290', '118635', '119024', '120162', '120172']],
#   'transitivity': None,
#   'word_id': 'arrangement_nn01'},
#  {'categories': {'region': [], 'register': [['rare']], 'topic': []},
#   'daterange': {'end': 1700,
#    'obsolete': True,
#    'rangestring': '1700',
#    'start': 1700},
#   'definition': 'A substance created by artificial means; a mixture, a compound. Obsolete. rare.',
#   'first_use': "Moxon's Mech. Exercises: Bricklayers-wks.",
#   'id': 'artifice_nn01-38521636',
#   'lemma': 'artifice',
#   'main_current_sense': False,
#   'meta': {'created': 1885,
#    'position_in_entry': 6,
#    'revised': True,
#    'sense_group': 'artifice_nn01-g05',
#    'updated': 2008},
#   'notes': [],
#   'oed_reference': 'artifice, n., sense 5b',
#   'oed_url': 'https://www.oed.com/view/Entry/11206#eid38521636',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['artifice_nn01-38521640'],
#   'semantic_class_ids': [['1',
#     '111290',
#     '118635',
#     '119024',
#     '120162',
#     '120172']],
#   'transitivity': None,
#   'word_id': 'artifice_nn01'},
#  {'categories': {'region': [], 'register': [], 'topic': []},
#   'daterange': {'end': 0, 'obsolete': True, 'rangestring': '?', 'start': 0},
#   'definition': 'A compacted body, structure.',
#   'first_use': None,
#   'id': 'compact_nn02-8786911',
#   'lemma': 'compact',
#   'main_current_sense': False,
#   'meta': {'created': 1891,
#    'position_in_entry': 1,
#    'revised': False,
#    'sense_group': 'compact_nn02-g01',
#    'updated': None},
#   'notes': [],
#   'oed_reference': 'compact, n.2, sense a',
#   'oed_url': 'https://www.oed.com/view/Entry/37367#eid8786911',
#   'part_of_speech': 'NN',
#   'quotation_ids': [],
#   'semantic_class_ids': [['1',
#     '111290',
#     '118635',
#     '119024',
#     '120162',
#     '120172']],
#   'transitivity': None,
#   'word_id': 'compact_nn02'},
#  {'categories': {'region': [], 'register': [], 'topic': []},
#   'daterange': {'end': 1624,
#    'obsolete': True,
#    'rangestring': '1624',
#    'start': 1624},
#   'definition': 'A structure.',
#   'first_use': 'Henry Wotton',
#   'id': 'compilement_nn01-8822441',
#   'lemma': 'compilement',
#   'main_current_sense': False,
#   'meta': {'created': 1891,
#    'position_in_entry': 4,
#    'revised': False,
#    'sense_group': 'compilement_nn01-g02',
#    'updated': None},
#   'notes': [],
#   'oed_reference': 'compilement, n., sense 2b',
#   'oed_url': 'https://www.oed.com/view/Entry/37596#eid8822441',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['compilement_nn01-8822446'],
#   'semantic_class_ids': [['1',
#     '111290',
#     '118635',
#     '119024',
#     '120162',
#     '120172']],
#   'transitivity': None,
#   'word_id': 'compilement_nn01'},
#  {'categories': {'region': [], 'register': [], 'topic': []},
#   'daterange': {'end': 1793,
#    'obsolete': True,
#    'rangestring': '1793',
#    'start': 1793},
#   'definition': 'A structure. Obsolete.',
#   'first_use': 'John Smeaton',
#   'id': 'composition_nn01-8851997',
#   'lemma': 'composition',
#   'main_current_sense': False,
#   'meta': {'created': 1891,
#    'position_in_entry': 32,
#    'revised': False,
#    'sense_group': 'composition_nn01-g20',
#    'updated': None},
#   'notes': [],
#   'oed_reference': 'composition, n., sense III.20b',
#   'oed_url': 'https://www.oed.com/view/Entry/37795#eid8851997',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['composition_nn01-8852001'],
#   'semantic_class_ids': [['1',
#     '111290',
#     '118635',
#     '119024',
#     '120162',
#     '120172']],
#   'transitivity': None,
#   'word_id': 'composition_nn01'},
#  {'categories': {'region': [], 'register': [], 'topic': []},
#   'daterange': {'end': 1773,
#    'obsolete': True,
#    'rangestring': '1607—1773',
#    'start': 1607},
#   'definition': 'A composition, a thing made up. Obsolete.',
#   'first_use': 'Thomas Walkington',
#   'id': 'compound_nn01-8598993',
#   'lemma': 'compound',
#   'main_current_sense': False,
#   'meta': {'created': 1891,
#    'position_in_entry': 7,
#    'revised': False,
#    'sense_group': 'compound_nn01-g03',
#    'updated': None},
#   'notes': [],
#   'oed_reference': 'compound, n.1, sense 3',
#   'oed_url': 'https://www.oed.com/view/Entry/37831#eid8598993',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['compound_nn01-8598997',
#    'compound_nn01-8599007',
#    'compound_nn01-8599017'],
#   'semantic_class_ids': [['1',
#     '111290',
#     '118635',
#     '119024',
#     '120162',
#     '120172']],
#   'transitivity': None,
#   'word_id': 'compound_nn01'},
#  {'categories': {'region': [], 'register': [['archaic']], 'topic': []},
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '1635—',
#    'start': 1635},
#   'definition': "A structure formed by joining timbers together, a piece of joiner's or carpenter's work; hence, any conjoined structure, framework, or ‘frame’ of things.",
#   'first_use': 'Joseph Hall',
#   'id': 'contignation_nn01-8444193',
#   'lemma': 'contignation',
#   'main_current_sense': False,
#   'meta': {'created': 1893,
#    'position_in_entry': 2,
#    'revised': False,
#    'sense_group': 'contignation_nn01-g02',
#    'updated': None},
#   'notes': [],
#   'oed_reference': 'contignation, n., sense 2',
#   'oed_url': 'https://www.oed.com/view/Entry/40222#eid8444193',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['contignation_nn01-8444196',
#    'contignation_nn01-8444206',
#    'contignation_nn01-8444214',
#    'contignation_nn01-8444223'],
#   'semantic_class_ids': [['1',
#     '111290',
#     '118635',
#     '119024',
#     '120162',
#     '120172']],
#   'transitivity': None,
#   'word_id': 'contignation_nn01'},
#  {'categories': {'region': [], 'register': [], 'topic': []},
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '1633—',
#    'start': 1633},
#   'definition': '‘Any body formed by the conjunction of dissimilar parts’ (Johnson); a frame, structure.',
#   'first_use': 'George Herbert',
#   'id': 'fabric_nn01-4917422',
#   'lemma': 'fabric',
#   'main_current_sense': False,
#   'meta': {'created': 1894,
#    'position_in_entry': 3,
#    'revised': False,
#    'sense_group': 'fabric_nn01-g03',
#    'updated': None},
#   'notes': [],
#   'oed_reference': 'fabric, n., sense I.3a',
#   'oed_url': 'https://www.oed.com/view/Entry/67394#eid4917422',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['fabric_nn01-4917425',
#    'fabric_nn01-4917435',
#    'fabric_nn01-4917444',
#    'fabric_nn01-4917453',
#    'fabric_nn01-4917463',
#    'fabric_nn01-4917472'],
#   'semantic_class_ids': [['1',
#     '111290',
#     '118635',
#     '119024',
#     '120162',
#     '120172']],
#   'transitivity': None,
#   'word_id': 'fabric_nn01'},
#  {'categories': {'region': [], 'register': [['rare']], 'topic': []},
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '1602—',
#    'start': 1602},
#   'definition': 'The action or process of fabricating (fabricate v. 1a); construction, fashioning, manufacture; also, a particular branch of manufacture. Now rare.',
#   'first_use': 'William Warner',
#   'id': 'fabrication_nn01-4918808',
#   'lemma': 'fabrication',
#   'main_current_sense': False,
#   'meta': {'created': 1894,
#    'position_in_entry': 1,
#    'revised': False,
#    'sense_group': 'fabrication_nn01-g01',
#    'updated': None},
#   'notes': [],
#   'oed_reference': 'fabrication, n., sense 1a',
#   'oed_url': 'https://www.oed.com/view/Entry/67399#eid4918808',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['fabrication_nn01-4918815',
#    'fabrication_nn01-4918826',
#    'fabrication_nn01-4918834',
#    'fabrication_nn01-4918842',
#    'fabrication_nn01-4918851',
#    'fabrication_nn01-4918861',
#    'fabrication_nn01-4918871',
#    'fabrication_nn01-4918880'],
#   'semantic_class_ids': [['153072', '208185', '208881', '208882', '208901'],
#    ['1', '111290', '118635', '119024', '120162', '120172'],
#    ['153072', '208185', '208881', '208882', '208901', '208904']],
#   'transitivity': None,
#   'word_id': 'fabrication_nn01'},
#  {'categories': {'region': [], 'register': [], 'topic': []},
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '1578—',
#    'start': 1578},
#   'definition': 'A structure made of parts joined to form a frame; esp. one designed to enclose or support; a frame or skeleton.',
#   'first_use': 'John Banister',
#   'id': 'framework_nn01-3636809',
#   'lemma': 'framework',
#   'main_current_sense': True,
#   'meta': {'created': 1897,
#    'position_in_entry': 1,
#    'revised': True,
#    'sense_group': 'framework_nn01-g01',
#    'updated': 2011},
#   'notes': [],
#   'oed_reference': 'framework, n., sense 1a',
#   'oed_url': 'https://www.oed.com/view/Entry/74161#eid3636809',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['framework_nn01-193666320',
#    'framework_nn01-3636813',
#    'framework_nn01-3636821',
#    'framework_nn01-202055688',
#    'framework_nn01-202055696',
#    'framework_nn01-3636829',
#    'framework_nn01-3636840',
#    'framework_nn01-202055706',
#    'framework_nn01-202055714',
#    'framework_nn01-202055722',
#    'framework_nn01-202055730'],
#   'semantic_class_ids': [['1',
#     '111290',
#     '118635',
#     '119024',
#     '120162',
#     '120172'],
#    ['1', '97163', '101153', '103213', '103360', '103371', '103408']],
#   'transitivity': None,
#   'word_id': 'framework_nn01'},
#  {'categories': {'region': [],
#    'register': [],
#    'topic': [['Military', 'Weaponry'],
#     ['Technology', 'Engineering', 'Mechanics']]},
#   'daterange': {'end': 1680,
#    'obsolete': True,
#    'rangestring': '1605—80',
#    'start': 1605},
#   'definition': 'A machine (esp. of war); a framework, mechanism, or apparatus. Also figurative. Obsolete.',
#   'first_use': 'Francis Bacon',
#   'id': 'machination_nn01-38473507',
#   'lemma': 'machination',
#   'main_current_sense': False,
#   'meta': {'created': 1904,
#    'position_in_entry': 3,
#    'revised': True,
#    'sense_group': 'machination_nn01-g03',
#    'updated': 2000},
#   'notes': [],
#   'oed_reference': 'machination, n., sense 3',
#   'oed_url': 'https://www.oed.com/view/Entry/111848#eid38473507',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['machination_nn01-38473512',
#    'machination_nn01-38473523',
#    'machination_nn01-38473532',
#    'machination_nn01-38473540'],
#   'semantic_class_ids': [['153072', '208185', '211995', '213839', '214572'],
#    ['1', '111290', '118635', '119024', '120162', '120172'],
#    ['153072', '160439', '163207', '163208', '163377', '163378']],
#   'transitivity': None,
#   'word_id': 'machination_nn01'},
#  {'categories': {'region': [], 'register': [['rare']], 'topic': []},
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '1545—',
#    'start': 1545},
#   'definition': 'A material or immaterial structure, esp. the fabric of the world or of the universe; a construction or edifice. Now rare.',
#   'first_use': 'J. Schäfer',
#   'id': 'machine_nn01-38473945',
#   'lemma': 'machine',
#   'main_current_sense': False,
#   'meta': {'created': 1904,
#    'position_in_entry': 1,
#    'revised': True,
#    'sense_group': 'machine_nn01-g01',
#    'updated': 2000},
#   'notes': [],
#   'oed_reference': 'machine, n., sense I.1a',
#   'oed_url': 'https://www.oed.com/view/Entry/111850#eid38473945',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['machine_nn01-38473950',
#    'machine_nn01-38473961',
#    'machine_nn01-38473973',
#    'machine_nn01-38473981',
#    'machine_nn01-38473999',
#    'machine_nn01-38474007',
#    'machine_nn01-38474047',
#    'machine_nn01-38474058',
#    'machine_nn01-38474068',
#    'machine_nn01-38474079',
#    'machine_nn01-38474089'],
#   'semantic_class_ids': [['1',
#     '111290',
#     '118635',
#     '119024',
#     '120162',
#     '120172'],
#    ['1', '111290', '118635', '119024', '120162', '120172', '120173']],
#   'transitivity': None,
#   'word_id': 'machine_nn01'},
#  {'categories': {'region': [], 'register': [], 'topic': []},
#   'daterange': {'end': 1770,
#    'obsolete': True,
#    'rangestring': '1712—70',
#    'start': 1712},
#   'definition': 'More generally: the interconnection of parts in any complex process, pattern, or arrangement. Obsolete.',
#   'first_use': 'Spectator',
#   'id': 'mechanism_nn01-37506198',
#   'lemma': 'mechanism',
#   'main_current_sense': False,
#   'meta': {'created': 1906,
#    'position_in_entry': 2,
#    'revised': True,
#    'sense_group': 'mechanism_nn01-g01',
#    'updated': 2001},
#   'notes': [],
#   'oed_reference': 'mechanism, n., sense I.1b',
#   'oed_url': 'https://www.oed.com/view/Entry/115557#eid37506198',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['mechanism_nn01-37506202',
#    'mechanism_nn01-37506211',
#    'mechanism_nn01-37506223',
#    'mechanism_nn01-37506231'],
#   'semantic_class_ids': [['1',
#     '111290',
#     '118635',
#     '119024',
#     '120162',
#     '120172']],
#   'transitivity': None,
#   'word_id': 'mechanism_nn01'},
#  {'categories': {'region': [], 'register': [], 'topic': []},
#   'daterange': {'end': None,
#    'obsolete': False,
#    'rangestring': '1612—',
#    'start': 1612},
#   'definition': 'Any framework or fabric of assembled material parts; a (typically large) man-made construction.',
#   'first_use': 'Samuel Daniel',
#   'id': 'structure_nn01-20269672',
#   'lemma': 'structure',
#   'main_current_sense': False,
#   'meta': {'created': 1919,
#    'position_in_entry': 15,
#    'revised': True,
#    'sense_group': 'structure_nn01-g06',
#    'updated': 2014},
#   'notes': [],
#   'oed_reference': 'structure, n., sense II.6',
#   'oed_url': 'https://www.oed.com/view/Entry/191895#eid20269672',
#   'part_of_speech': 'NN',
#   'quotation_ids': ['structure_nn01-278565247',
#    'structure_nn01-20269675',
#    'structure_nn01-20269683',
#    'structure_nn01-20269693',
#    'structure_nn01-292525151',
#    'structure_nn01-20269709',
#    'structure_nn01-292525159',
#    'structure_nn01-278928077',
#    'structure_nn01-292525167',
#    'structure_nn01-292525175'],
#   'semantic_class_ids': [['1', '82596', '83404', '83917', '83947', '83955'],
#    ['1', '111290', '118635', '119024', '120162', '120172']],
#   'transitivity': None,
#   'word_id': 'structure_nn01'}]

# %%
len(entry_sensessem['data'])
# Out:
# 14

# %% [markdown]
# These are all the other entries which have a sense linked to semantic class 120172:

# %%
for i in range(len(entry_sensessem['data'])):
    print(entry_sensessem['data'][i]['lemma'])
    #print(entry_sensessem['data'][i]['definition'])
# Out:
# arrangement
# artifice
# compact
# compilement
# composition
# compound
# contignation
# fabric
# fabrication
# framework
# machination
# machine
# mechanism
# structure

# %% [markdown]
# And these are the entry IDs:

# %%
for i in range(len(entry_sensessem['data'])):
    print(entry_sensessem['data'][i]['word_id'])
    #print(entry_sensessem['data'][i]['definition'])
# Out:
# arrangement_nn01
# artifice_nn01
# compact_nn02
# compilement_nn01
# composition_nn01
# compound_nn01
# contignation_nn01
# fabric_nn01
# fabrication_nn01
# framework_nn01
# machination_nn01
# machine_nn01
# mechanism_nn01
# structure_nn01

# %% [markdown]
# Let's extract all entries related to the semantic classess associated to the senses of machine, n. that were current in 1789:

# %%
for j in range(len(entry_senses['data'])):
    
    print("sense number", str(j))
    e = entry_senses['data'][j]
    if e['daterange']['end'] is None or int(e['daterange']['end'])>= 1789:
        definition = e['definition']
        print("definition:", definition)
        semantic_class_ids = e['semantic_class_ids']
        for i in range(len(semantic_class_ids)):
            print("\tset of semantic classes number", str(i))
            for sem_id in semantic_class_ids[i]:
                url_sem = "https://oed-researcher-api.oxfordlanguages.com/oed/api/v0.2/semanticclass/" + str(sem_id)
                r_sem = requests.get(url_sem, headers = {"app_id": app_id, "app_key": app_key})
                entry_json_sem = json.dumps(r_sem.json())
                entry_sem = json.loads(entry_json_sem)
                #print(str(entry_sem))
                print("\t\tsemantic class id:", sem_id, "label:", entry_sem['data']['label'])
                url_sensessem = "https://oed-researcher-api.oxfordlanguages.com/oed/api/v0.2/semanticclass/" + str(sem_id) + "/senses/"
                r_sensessem = requests.get(url_sensessem, headers = {"app_id": app_id, "app_key": app_key})
                entry_json_sensessem = json.dumps(r_sensessem.json())
                entry_sensessem = json.loads(entry_json_sensessem)
                for i in range(len(entry_sensessem['data'])):
                    print("\t\t\tword associated to this semantic class", entry_sensessem['data'][i]['lemma'],
                          "(", entry_sensessem['data'][i]['word_id'], ")")
                    #print(entry_sensessem['data'][i]['definition'])
# Out:
# sense number 0
# definition: A material or immaterial structure, esp. the fabric of the world or of the universe; a construction or edifice. Now rare.
# 	set of semantic classes number 0
# 		semantic class id: 1 label: the world
# 		semantic class id: 111290 label: relative properties
# 		semantic class id: 118635 label: wholeness
# 		semantic class id: 119024 label: mutual relation of parts to whole
# 		semantic class id: 120162 label: None
# 			word associated to this semantic class architecture ( architecture_nn01 )
# 			word associated to this semantic class compacture ( compacture_nn01 )
# 			word associated to this semantic class compage ( compage_nn01 )
# 			word associated to this semantic class compages ( compages_nn01 )
# 			word associated to this semantic class componency ( componency_nn01 )
# 			word associated to this semantic class composier ( composier_nn01 )
# 			word associated to this semantic class composition ( composition_nn01 )
# 			word associated to this semantic class compositure ( compositure_nn01 )
# 			word associated to this semantic class composture ( composture_nn01 )
# 			word associated to this semantic class composure ( composure_nn01 )
# 			word associated to this semantic class compound ( compound_nn01 )
# 			word associated to this semantic class confection ( confection_nn01 )
# 			word associated to this semantic class conformation ( conformation_nn01 )
# 			word associated to this semantic class constitution ( constitution_nn01 )
# 			word associated to this semantic class construction ( construction_nn01 )
# 			word associated to this semantic class constructure ( constructure_nn01 )
# 			word associated to this semantic class contexture ( contexture_nn01 )
# 			word associated to this semantic class economy ( economy_nn01 )
# 			word associated to this semantic class fabric ( fabric_nn01 )
# 			word associated to this semantic class fabricature ( fabricature_nn01 )
# 			word associated to this semantic class formation ( formation_nn01 )
# 			word associated to this semantic class frame ( frame_nn01 )
# 			word associated to this semantic class make-up ( makeup_nn01 )
# 			word associated to this semantic class mechanism ( mechanism_nn01 )
# 			word associated to this semantic class membrature ( membrature_nn01 )
# 			word associated to this semantic class shape ( shape_nn01 )
# 			word associated to this semantic class structure ( structure_nn01 )
# 			word associated to this semantic class temper ( temper_nn01 )
# 			word associated to this semantic class temperament ( temperament_nn01 )
# 		semantic class id: 120172 label: a structure
# 			word associated to this semantic class arrangement ( arrangement_nn01 )
# 			word associated to this semantic class artifice ( artifice_nn01 )
# 			word associated to this semantic class compact ( compact_nn02 )
# 			word associated to this semantic class compilement ( compilement_nn01 )
# 			word associated to this semantic class composition ( composition_nn01 )
# 			word associated to this semantic class compound ( compound_nn01 )
# 			word associated to this semantic class contignation ( contignation_nn01 )
# 			word associated to this semantic class fabric ( fabric_nn01 )
# 			word associated to this semantic class fabrication ( fabrication_nn01 )
# 			word associated to this semantic class framework ( framework_nn01 )
# 			word associated to this semantic class machination ( machination_nn01 )
# 			word associated to this semantic class machine ( machine_nn01 )
# 			word associated to this semantic class mechanism ( mechanism_nn01 )
# 			word associated to this semantic class structure ( structure_nn01 )
# 	set of semantic classes number 1
# 		semantic class id: 1 label: the world
# 		semantic class id: 111290 label: relative properties
# 		semantic class id: 118635 label: wholeness
# 		semantic class id: 119024 label: mutual relation of parts to whole
# 		semantic class id: 120162 label: None
# 			word associated to this semantic class architecture ( architecture_nn01 )
# 			word associated to this semantic class compacture ( compacture_nn01 )
# 			word associated to this semantic class compage ( compage_nn01 )
# 			word associated to this semantic class compages ( compages_nn01 )
# 			word associated to this semantic class componency ( componency_nn01 )
# 			word associated to this semantic class composier ( composier_nn01 )
# 			word associated to this semantic class composition ( composition_nn01 )
# 			word associated to this semantic class compositure ( compositure_nn01 )
# 			word associated to this semantic class composture ( composture_nn01 )
# 			word associated to this semantic class composure ( composure_nn01 )
# 			word associated to this semantic class compound ( compound_nn01 )
# 			word associated to this semantic class confection ( confection_nn01 )
# 			word associated to this semantic class conformation ( conformation_nn01 )
# 			word associated to this semantic class constitution ( constitution_nn01 )
# 			word associated to this semantic class construction ( construction_nn01 )
# 			word associated to this semantic class constructure ( constructure_nn01 )
# 			word associated to this semantic class contexture ( contexture_nn01 )
# 			word associated to this semantic class economy ( economy_nn01 )
# 			word associated to this semantic class fabric ( fabric_nn01 )
# 			word associated to this semantic class fabricature ( fabricature_nn01 )
# 			word associated to this semantic class formation ( formation_nn01 )
# 			word associated to this semantic class frame ( frame_nn01 )
# 			word associated to this semantic class make-up ( makeup_nn01 )
# 			word associated to this semantic class mechanism ( mechanism_nn01 )
# 			word associated to this semantic class membrature ( membrature_nn01 )
# 			word associated to this semantic class shape ( shape_nn01 )
# 			word associated to this semantic class structure ( structure_nn01 )
# 			word associated to this semantic class temper ( temper_nn01 )
# 			word associated to this semantic class temperament ( temperament_nn01 )
# 		semantic class id: 120172 label: a structure
# 			word associated to this semantic class arrangement ( arrangement_nn01 )
# 			word associated to this semantic class artifice ( artifice_nn01 )
# 			word associated to this semantic class compact ( compact_nn02 )
# 			word associated to this semantic class compilement ( compilement_nn01 )
# 			word associated to this semantic class composition ( composition_nn01 )
# 			word associated to this semantic class compound ( compound_nn01 )
# 			word associated to this semantic class contignation ( contignation_nn01 )
# 			word associated to this semantic class fabric ( fabric_nn01 )
# 			word associated to this semantic class fabrication ( fabrication_nn01 )
# 			word associated to this semantic class framework ( framework_nn01 )
# 			word associated to this semantic class machination ( machination_nn01 )
# 			word associated to this semantic class machine ( machine_nn01 )
# 			word associated to this semantic class mechanism ( mechanism_nn01 )
# 			word associated to this semantic class structure ( structure_nn01 )
# 		semantic class id: 120173 label: immaterial
# 			word associated to this semantic class cadre ( cadre_nn01 )
# 			word associated to this semantic class machina ( machina_nn01 )
# 			word associated to this semantic class machinament ( machinament_nn01 )
# 			word associated to this semantic class machine ( machine_nn01 )
# sense number 1
# definition: A military engine or siege-tower. Cf. war machine n. (a) at  war n.1 compounds 4. Now historical.
# 	set of semantic classes number 0
# 		semantic class id: 153072 label: society
# 		semantic class id: 160439 label: armed hostility
# 		semantic class id: 163207 label: military equipment
# 		semantic class id: 163208 label: weapon
# 		semantic class id: 163377 label: engine of war
# 		semantic class id: 163378 label: None
# 			word associated to this semantic class engine ( engine_nn01 )
# 			word associated to this semantic class gun ( gun_nn01 )
# 			word associated to this semantic class machinament ( machinament_nn01 )
# 			word associated to this semantic class machination ( machination_nn01 )
# 			word associated to this semantic class machine ( machine_nn01 )
# sense number 2
# sense number 3
# definition: A living body, esp. the human body considered in general or individually. Now chiefly figurative from sense 6b (cf. sense 8b).
# 	set of semantic classes number 0
# 		semantic class id: 1 label: the world
# 		semantic class id: 8835 label: life
# 		semantic class id: 25507 label: the body
# 		semantic class id: 29189 label: None
# 			word associated to this semantic class anatomy ( anatomy_nn01 )
# 			word associated to this semantic class automaton ( automaton_nn01 )
# 			word associated to this semantic class belly ( belly_nn01 )
# 			word associated to this semantic class blood bulk ( bloodbulk_nn01 )
# 			word associated to this semantic class bodiȝlich ( bodiglich_nn01 )
# 			word associated to this semantic class body ( body_nn01 )
# 			word associated to this semantic class bone house ( bonehouse_nn01 )
# 			word associated to this semantic class bones ( bone_nn01 )
# 			word associated to this semantic class bouk ( bouk_nn01 )
# 			word associated to this semantic class bulk ( bulk_nn01 )
# 			word associated to this semantic class cabinet ( cabinet_nn01 )
# 			word associated to this semantic class carcass ( carcass_nn01 )
# 			word associated to this semantic class carrion ( carrion_nn01 )
# 			word associated to this semantic class case ( case_nn02 )
# 			word associated to this semantic class case ( case_nn02 )
# 			word associated to this semantic class chassis ( chassis_nn01 )
# 			word associated to this semantic class clay ( clay_nn01 )
# 			word associated to this semantic class clod ( clod_nn01 )
# 			word associated to this semantic class corporation ( corporation_nn01 )
# 			word associated to this semantic class corporeity ( corporeity_nn01 )
# 			word associated to this semantic class corpse ( corpse_nn01 )
# 			word associated to this semantic class corpus ( corpus_nn01 )
# 			word associated to this semantic class corse ( corse_nn01 )
# 			word associated to this semantic class dust ( dust_nn01 )
# 			word associated to this semantic class earth ( earth_nn01 )
# 			word associated to this semantic class embodiment ( embodiment_nn01 )
# 			word associated to this semantic class flesh ( flesh_nn01 )
# 			word associated to this semantic class flesh-rind ( fleshrind_nn01 )
# 			word associated to this semantic class flesh-stuff ( fleshstuff_nn01 )
# 			word associated to this semantic class God's image ( godsimage_nn01 )
# 			word associated to this semantic class incarnation ( incarnation_nn01 )
# 			word associated to this semantic class lay ( lay_jj01 )
# 			word associated to this semantic class lich ( lich_nn01 )
# 			word associated to this semantic class licham ( licham_nn01 )
# 			word associated to this semantic class lump of clay ( lumpofclay_nn01 )
# 			word associated to this semantic class machina ( machina_nn01 )
# 			word associated to this semantic class machine ( machine_nn01 )
# 			word associated to this semantic class man ( man_nn01 )
# 			word associated to this semantic class microcosm ( microcosm_nn01 )
# 			word associated to this semantic class mud wall ( mudwall_nn01 )
# 			word associated to this semantic class outwall ( outwall_nn01 )
# 			word associated to this semantic class outward man ( outward_jj01 )
# 			word associated to this semantic class person ( person_nn01 )
# 			word associated to this semantic class personage ( personage_nn01 )
# 			word associated to this semantic class personality ( personality_nn01 )
# 			word associated to this semantic class quarrons ( quarrons_nn01 )
# 			word associated to this semantic class sensuality ( sensuality_nn01 )
# 			word associated to this semantic class skinful ( skinful_nn01 )
# 			word associated to this semantic class slime ( slime_nn01 )
# 			word associated to this semantic class soma ( soma_nn02 )
# 			word associated to this semantic class soul case ( soulcase_nn02 )
# 			word associated to this semantic class structure ( structure_nn01 )
# 			word associated to this semantic class tabernacle ( tabernacle_nn01 )
# 			word associated to this semantic class utter man ( utterman_nn01 )
# 			word associated to this semantic class vessel ( vessel_nn01 )
# sense number 4
# definition: Theatre. A (usually movable) contrivance for the production of stage-effects; (in plural) stage machinery. Also figurative. Cf. god from the machine at  god n. int.phrases 4e and deus ex machina n. Now historical and poetic.
# 	set of semantic classes number 0
# 		semantic class id: 153072 label: society
# 		semantic class id: 222360 label: leisure
# 		semantic class id: 224508 label: the arts
# 		semantic class id: 232933 label: performance arts
# 		semantic class id: 232967 label: the theatre or the stage
# 		semantic class id: 233050 label: a theatre
# 		semantic class id: 233119 label: theatrical equipment or accessories
# 		semantic class id: 233127 label: None
# 		semantic class id: 233139 label: machinery for effects
# 			word associated to this semantic class ficelle ( ficelle_nn01 )
# 			word associated to this semantic class machine ( machine_nn01 )
# 			word associated to this semantic class machinery ( machinery_nn01 )
# 			word associated to this semantic class pageant ( pageant_nn01 )
# sense number 5
# definition: A ship or other vessel. Now colloquial: a boat.
# 	set of semantic classes number 0
# 		semantic class id: 153072 label: society
# 		semantic class id: 198379 label: travel
# 		semantic class id: 202986 label: travel by water
# 		semantic class id: 204466 label: vessel, ship, or boat
# 		semantic class id: 206654 label: None
# 			word associated to this semantic class ark ( ark_nn01 )
# 			word associated to this semantic class barge ( barge_nn01 )
# 			word associated to this semantic class bark ( bark_nn02 )
# 			word associated to this semantic class bastiment ( bastiment_nn01 )
# 			word associated to this semantic class beam ( beam_nn01 )
# 			word associated to this semantic class board ( board_nn01 )
# 			word associated to this semantic class bottom ( bottom_nn01 )
# 			word associated to this semantic class class ( class_nn01 )
# 			word associated to this semantic class craft ( craft_nn01 )
# 			word associated to this semantic class embarkation ( embarkation_nn01 )
# 			word associated to this semantic class flood-bickerer ( floodbickerer_nn01 )
# 			word associated to this semantic class hooker ( hooker_nn02 )
# 			word associated to this semantic class keel ( keel_nn01 )
# 			word associated to this semantic class loom ( loom_nn01 )
# 			word associated to this semantic class machine ( machine_nn01 )
# 			word associated to this semantic class man ( man_nn01 )
# 			word associated to this semantic class M.F.V. ( mfv_nn01 )
# 			word associated to this semantic class Mudian ( mudian_nn01 )
# 			word associated to this semantic class nymph ( nymph_nn01 )
# 			word associated to this semantic class pine ( pine_nn02 )
# 			word associated to this semantic class pitchboard ( pitchboard_nn01 )
# 			word associated to this semantic class prore ( prore_nn01 )
# 			word associated to this semantic class prow ( prow_nn02 )
# 			word associated to this semantic class ship ( ship_nn01 )
# 			word associated to this semantic class steer ( steer_nn02 )
# 			word associated to this semantic class stern-bearer ( sternbearer_nn01 )
# 			word associated to this semantic class tree ( tree_nn01 )
# 			word associated to this semantic class vessel ( vessel_nn01 )
# 			word associated to this semantic class watercraft ( watercraft_nn01 )
# 			word associated to this semantic class water house ( waterhouse_nn01 )
# 			word associated to this semantic class water treader ( watertreader_nn01 )
# 			word associated to this semantic class wooden horse ( wooden_jj01 )
# 			word associated to this semantic class wooden isle ( woodenisle_nn01 )
# sense number 6
# definition: In general use: an apparatus, device, instrument, or implement (now archaic and Canadian regional (Newfoundland)); an appliance; a vending machine. Cf. sense 6c.
# 	set of semantic classes number 0
# 		semantic class id: 1 label: the world
# 		semantic class id: 84689 label: action or operation
# 		semantic class id: 87987 label: advantage
# 		semantic class id: 87988 label: usefulness
# 		semantic class id: 87989 label: use (made of things)
# 		semantic class id: 88083 label: instrumentality
# 		semantic class id: 88109 label: None
# 			word associated to this semantic class agency ( agency_nn01 )
# 			word associated to this semantic class canal ( canal_nn01 )
# 			word associated to this semantic class instrumency ( instrumency_nn01 )
# 			word associated to this semantic class instrumentality ( instrumentality_nn01 )
# 			word associated to this semantic class instrumentalness ( instrumentalness_nn01 )
# 			word associated to this semantic class instrumentation ( instrumentation_nn01 )
# 			word associated to this semantic class ministration ( ministration_nn01 )
# 			word associated to this semantic class ministry ( ministry_nn01 )
# 			word associated to this semantic class moyen ( moyen_nn01 )
# 		semantic class id: 88117 label: (a) means
# 			word associated to this semantic class agency ( agency_nn01 )
# 			word associated to this semantic class agent ( agent_nn01 )
# 			word associated to this semantic class appliance ( appliance_nn01 )
# 			word associated to this semantic class blade ( blade_nn01 )
# 			word associated to this semantic class engine ( engine_nn01 )
# 			word associated to this semantic class executioner ( executioner_nn01 )
# 			word associated to this semantic class expedient ( expedient_nn01 )
# 			word associated to this semantic class facility ( facility_nn01 )
# 			word associated to this semantic class hackney ( hackney_nn01 )
# 			word associated to this semantic class handle ( handle_nn01 )
# 			word associated to this semantic class ingine ( ingine_nn01 )
# 			word associated to this semantic class instrument ( instrument_nn01 )
# 			word associated to this semantic class instrumental ( instrumental_nn01 )
# 			word associated to this semantic class instrumentality ( instrumentality_nn01 )
# 			word associated to this semantic class key ( key_nn01 )
# 			word associated to this semantic class matter ( matter_nn01 )
# 			word associated to this semantic class mean ( mean_nn03 )
# 			word associated to this semantic class mean ( mean_nn03 )
# 			word associated to this semantic class mechanic ( mechanic_nn01 )
# 			word associated to this semantic class mechanism ( mechanism_nn01 )
# 			word associated to this semantic class mesne ( mesne_nn01 )
# 			word associated to this semantic class mids ( mids_nn01 )
# 			word associated to this semantic class minister ( minister_nn01 )
# 			word associated to this semantic class moyen ( moyen_nn01 )
# 			word associated to this semantic class operative ( operative_nn01 )
# 			word associated to this semantic class operatory ( operatory_nn02 )
# 			word associated to this semantic class organ ( organ_nn01 )
# 			word associated to this semantic class organy ( organy_nn03 )
# 			word associated to this semantic class procurement ( procurement_nn01 )
# 			word associated to this semantic class receipt ( receipt_nn01 )
# 			word associated to this semantic class Roaring Meg ( roaringmeg_nn01 )
# 			word associated to this semantic class shoeing-horn ( shoeinghorn_nn01 )
# 			word associated to this semantic class tool ( tool_nn01 )
# 			word associated to this semantic class vehicle ( vehicle_nn01 )
# 			word associated to this semantic class wedge ( wedge_nn01 )
# 			word associated to this semantic class wherewith ( wherewith_rb01 )
# 			word associated to this semantic class wherewithal ( wherewithal_rb01 )
# 		semantic class id: 88146 label: equipment for any action or undertaking
# 			word associated to this semantic class accoutrements ( accoutrement_nn01 )
# 			word associated to this semantic class apparate ( apparate_nn01 )
# 			word associated to this semantic class apparatus ( apparatus_nn01 )
# 			word associated to this semantic class apparel ( apparel_nn01 )
# 			word associated to this semantic class apparelment ( apparelment_nn01 )
# 			word associated to this semantic class apparement ( apparement_nn01 )
# 			word associated to this semantic class appoint ( appoint_nn01 )
# 			word associated to this semantic class appointment ( appointment_nn01 )
# 			word associated to this semantic class appurtenance ( appurtenance_nn01 )
# 			word associated to this semantic class atil ( atil_nn01 )
# 			word associated to this semantic class attirail ( attirail_nn01 )
# 			word associated to this semantic class clobber ( clobber_nn02 )
# 			word associated to this semantic class conrey ( conrey_nn01 )
# 			word associated to this semantic class coutrement ( coutrement_nn01 )
# 			word associated to this semantic class dighting ( dighting_nn01 )
# 			word associated to this semantic class equipage ( equipage_nn01 )
# 			word associated to this semantic class equipment ( equipment_nn01 )
# 			word associated to this semantic class fare ( fare_nn01 )
# 			word associated to this semantic class farrements ( farrement_nn01 )
# 			word associated to this semantic class fitting ( fitting_nn01b )
# 			word associated to this semantic class fixing ( fixing_nn01 )
# 			word associated to this semantic class fixture ( fixture_nn01 )
# 			word associated to this semantic class furniments ( furniment_nn01 )
# 			word associated to this semantic class garnishing ( garnishing_nn01 )
# 			word associated to this semantic class garniture ( garniture_nn01 )
# 			word associated to this semantic class gear ( gear_nn01 )
# 			word associated to this semantic class graith ( graith_nn01 )
# 			word associated to this semantic class habiliments ( habiliment_nn01 )
# 			word associated to this semantic class harness ( harness_nn01 )
# 			word associated to this semantic class implements ( implement_nn01 )
# 			word associated to this semantic class instrument ( instrument_nn01 )
# 			word associated to this semantic class i-wende ( iwende_nn01 )
# 			word associated to this semantic class materials ( material_nn01 )
# 			word associated to this semantic class matériel ( materiel_nn01 )
# 			word associated to this semantic class muniments ( muniment_nn01 )
# 			word associated to this semantic class ordinance ( ordinance_nn01 )
# 			word associated to this semantic class ordinar ( ordinar_nn01 )
# 			word associated to this semantic class ornament ( ornament_nn01 )
# 			word associated to this semantic class ornation ( ornation_nn01 )
# 			word associated to this semantic class outfit ( outfit_nn01 )
# 			word associated to this semantic class outred ( outred_nn01 )
# 			word associated to this semantic class outreik ( outreik_nn01 )
# 			word associated to this semantic class outreiking ( outreiking_nn01 )
# 			word associated to this semantic class parapherna ( parapherna_nn01 )
# 			word associated to this semantic class paraphernalia ( paraphernalia_nn01 )
# 			word associated to this semantic class parel ( parel_nn01 )
# 			word associated to this semantic class parelling ( parelling_nn01 )
# 			word associated to this semantic class reparel ( reparel_nn01 )
# 			word associated to this semantic class rigging ( rigging_nn02 )
# 			word associated to this semantic class set-out ( setout_nn01 )
# 			word associated to this semantic class skippeson ( skippeson_nn01 )
# 			word associated to this semantic class stuff ( stuff_nn01 )
# 			word associated to this semantic class stuffure ( stuffure_nn01 )
# 			word associated to this semantic class supellectile ( supellectile_nn01 )
# 			word associated to this semantic class tack ( tack_nn07 )
# 			word associated to this semantic class tackle ( tackle_nn01 )
# 			word associated to this semantic class tackling ( tackling_nn01 )
# 			word associated to this semantic class thing ( thing_nn01 )
# 			word associated to this semantic class tire ( tire_nn01 )
# 			word associated to this semantic class trinket ( trinket_nn01 )
# 			word associated to this semantic class warnement ( warnement_nn01 )
# 		semantic class id: 88147 label: a device or contrivance
# 			word associated to this semantic class address ( address_nn01 )
# 			word associated to this semantic class affair ( affair_nn01 )
# 			word associated to this semantic class art ( art_nn01 )
# 			word associated to this semantic class cautel ( cautel_nn01 )
# 			word associated to this semantic class compassing ( compassing_nn01 )
# 			word associated to this semantic class contraption ( contraption_nn01 )
# 			word associated to this semantic class convenience ( convenience_nn01 )
# 			word associated to this semantic class conveniency ( conveniency_nn01 )
# 			word associated to this semantic class conveyance ( conveyance_nn01 )
# 			word associated to this semantic class device ( device_nn01 )
# 			word associated to this semantic class fabric ( fabric_nn01 )
# 			word associated to this semantic class fancy ( fancy_nn01 )
# 			word associated to this semantic class fanglement ( fanglement_nn01 )
# 			word associated to this semantic class fashion ( fashion_nn01 )
# 			word associated to this semantic class frame ( frame_nn01 )
# 			word associated to this semantic class graith ( graith_nn01 )
# 			word associated to this semantic class invention ( invention_nn01 )
# 			word associated to this semantic class jet ( jet_nn01 )
# 			word associated to this semantic class machine ( machine_nn01 )
# 			word associated to this semantic class molition ( molition_nn01 )
# 			word associated to this semantic class quaint ( quaint_nn02 )
# 			word associated to this semantic class rig ( rig_nn03 )
# 			word associated to this semantic class trick ( trick_nn01 )
# 	set of semantic classes number 1
# 		semantic class id: 153072 label: society
# 		semantic class id: 208185 label: occupation and work
# 		semantic class id: 211995 label: equipment
# 		semantic class id: 211996 label: tool
# 		semantic class id: 212078 label: None
# 			word associated to this semantic class appliance ( appliance_nn01 )
# 			word associated to this semantic class contrivance ( contrivance_nn01 )
# 			word associated to this semantic class conveniency ( conveniency_nn01 )
# 			word associated to this semantic class device ( device_nn01 )
# 			word associated to this semantic class dial ( dial_nn01 )
# 			word associated to this semantic class dog ( dog_nn01 )
# 			word associated to this semantic class gin ( gin_nn01 )
# 			word associated to this semantic class implements ( implement_nn01 )
# 			word associated to this semantic class instrument ( instrument_nn01 )
# 			word associated to this semantic class loom ( loom_nn01 )
# 			word associated to this semantic class machinament ( machinament_nn01 )
# 			word associated to this semantic class machine ( machine_nn01 )
# 			word associated to this semantic class mister ( mister_nn01 )
# 			word associated to this semantic class oustil ( oustil_nn01 )
# 			word associated to this semantic class ruler ( ruler_nn01 )
# 			word associated to this semantic class tool ( tool_nn01 )
# 			word associated to this semantic class utensil ( utensil_nn01 )
# 			word associated to this semantic class work-loom ( workloom_nn01 )
# sense number 7
# definition: A complex device, consisting of a number of interrelated parts, each having a definite function, together applying, using, or generating mechanical or (later) electrical power to perform a certain kind of work (often specified by a preceding verbal noun).
# 	set of semantic classes number 0
# 		semantic class id: 153072 label: society
# 		semantic class id: 208185 label: occupation and work
# 		semantic class id: 211995 label: equipment
# 		semantic class id: 213839 label: machine
# 		semantic class id: 214572 label: None
# 			word associated to this semantic class contrivance ( contrivance_nn01 )
# 			word associated to this semantic class engine ( engine_nn01 )
# 			word associated to this semantic class gimcrack ( gimcrack_nn01 )
# 			word associated to this semantic class gin ( gin_nn01 )
# 			word associated to this semantic class machina ( machina_nn01 )
# 			word associated to this semantic class machination ( machination_nn01 )
# 			word associated to this semantic class machine ( machine_nn01 )
# 			word associated to this semantic class mechanism ( mechanism_nn01 )
# 			word associated to this semantic class pageant ( pageant_nn01 )
# 			word associated to this semantic class plant ( plant_nn01 )
# 			word associated to this semantic class power ( power_nn01 )
# 			word associated to this semantic class tram ( tram_nn01 )
# sense number 8
# definition: In literature, etc.: a contrivance for the sake of effect; a supernatural agency, personage, or incident introduced into a narrative; the interposition of one of these. Now rare.
# sense number 9
# definition: figurative in general use.
# sense number 10
# definition: figurative. A living being considered to move or act automatically or mechanically, rather than of its own volition; esp. a person who acts mechanically or unthinkingly, as from habit or obedience; a person who acts with mechanical precision or efficiency. Also: a system or organization of an impersonal or inflexible character.
# 	set of semantic classes number 0
# 		semantic class id: 122209 label: the mind
# 		semantic class id: 122210 label: mental capacity
# 		semantic class id: 124580 label: lack of understanding
# 		semantic class id: 124795 label: None
# 			word associated to this semantic class brainlessness ( brainlessness_nn01 )
# 			word associated to this semantic class headlesshood ( headlesshood_nn01 )
# 			word associated to this semantic class inapprehension ( inapprehension_nn01 )
# 			word associated to this semantic class inapprehensiveness ( inapprehensiveness_nn01 )
# 			word associated to this semantic class incomprehension ( incomprehension_nn01 )
# 			word associated to this semantic class inconception ( inconception_nn01 )
# 			word associated to this semantic class insensateness ( insensateness_nn01 )
# 			word associated to this semantic class insensibleness ( insensibleness_nn01 )
# 			word associated to this semantic class mindlessness ( mindlessness_nn01 )
# 			word associated to this semantic class non-intelligence ( nonintelligence_nn01 )
# 			word associated to this semantic class senselessness ( senselessness_nn01 )
# 			word associated to this semantic class unapprehensiveness ( unapprehensiveness_nn01 )
# 			word associated to this semantic class uncomprehension ( uncomprehension_nn01 )
# 			word associated to this semantic class unintelligibleness ( unintelligibleness_nn01 )
# 			word associated to this semantic class unperceivingness ( unperceivingness_nn01 )
# 			word associated to this semantic class unsensibleness ( unsensibleness_nn01 )
# 			word associated to this semantic class vacancy ( vacancy_nn01 )
# 			word associated to this semantic class vacuity ( vacuity_nn01 )
# 		semantic class id: 124796 label: creature showing
# 			word associated to this semantic class machina ( machina_nn01 )
# 			word associated to this semantic class machine ( machine_nn01 )
# 	set of semantic classes number 1
# 		semantic class id: 122209 label: the mind
# 		semantic class id: 142646 label: will
# 		semantic class id: 143483 label: intention
# 		semantic class id: 143639 label: unintentional or unplanned character
# 		semantic class id: 143654 label: None
# 		semantic class id: 143655 label: unintentional or involuntary quality
# 			word associated to this semantic class indeliberateness ( indeliberateness_nn01 )
# 			word associated to this semantic class involuntariness ( involuntariness_nn01 )
# 			word associated to this semantic class unintentionality ( unintentionality_nn01 )
# 			word associated to this semantic class unintentness ( unintentness_nn01 )
# 			word associated to this semantic class unmeaningness ( unmeaningness_nn01 )
# 			word associated to this semantic class unwittingness ( unwittingness_nn01 )
# 		semantic class id: 143656 label: automatic or mechanical quality
# 			word associated to this semantic class automacy ( automacy_nn01 )
# 			word associated to this semantic class automaticity ( automaticity_nn01 )
# 			word associated to this semantic class automatism ( automatism_nn01 )
# 			word associated to this semantic class automatonism ( automatonism_nn01 )
# 			word associated to this semantic class mechanicality ( mechanicality_nn01 )
# 			word associated to this semantic class mechanicalness ( mechanicalness_nn01 )
# 			word associated to this semantic class robotism ( robotism_nn01 )
# 			word associated to this semantic class robotry ( robotry_nn01 )
# 		semantic class id: 143657 label: person acting with
# 			word associated to this semantic class golem ( golem_nn01 )
# 			word associated to this semantic class machina ( machina_nn01 )
# 			word associated to this semantic class machine ( machine_nn01 )
# 			word associated to this semantic class man-machine ( manmachine_nn01 )
# 			word associated to this semantic class robot ( robot_nn02 )
# sense number 11
# definition: A (usually wheeled) vehicle or conveyance, esp. one drawn by a horse or horses, or other draught animal or animals. Formerly esp.: a stagecoach or mail coach; (also) a brake, trap, or small carriage (chiefly Scottish). Now historical.
# 	set of semantic classes number 0
# 		semantic class id: 153072 label: society
# 		semantic class id: 198379 label: travel
# 		semantic class id: 200757 label: means of travel
# 		semantic class id: 201351 label: a conveyance
# 		semantic class id: 202575 label: None
# 			word associated to this semantic class carriage ( carriage_nn01 )
# 			word associated to this semantic class convenience ( convenience_nn01 )
# 			word associated to this semantic class conveniency ( conveniency_nn01 )
# 			word associated to this semantic class conveyance ( conveyance_nn01 )
# 			word associated to this semantic class machine ( machine_nn01 )
# 			word associated to this semantic class passage ( passage_nn01 )
# 			word associated to this semantic class port ( port_nn04 )
# 			word associated to this semantic class transportation ( transportation_nn01 )
# 			word associated to this semantic class vehicle ( vehicle_nn01 )
# 			word associated to this semantic class voiture ( voiture_nn01 )
# 	set of semantic classes number 1
# 		semantic class id: 153072 label: society
# 		semantic class id: 198379 label: travel
# 		semantic class id: 200757 label: means of travel
# 		semantic class id: 201351 label: a conveyance
# 		semantic class id: 201370 label: vehicle
# 		semantic class id: 202530 label: None
# 			word associated to this semantic class chariot ( chariot_nn01 )
# 			word associated to this semantic class machinament ( machinament_nn01 )
# 			word associated to this semantic class machine ( machine_nn01 )
# 			word associated to this semantic class rig ( rig_nn03 )
# 			word associated to this semantic class shebang ( shebang_nn01 )
# 			word associated to this semantic class triumphal ( triumphal_nn01 )
# 			word associated to this semantic class vehicle ( vehicle_nn01 )
# 			word associated to this semantic class vehiculum ( vehiculum_nn01 )
# 	set of semantic classes number 2
# 		semantic class id: 153072 label: society
# 		semantic class id: 198379 label: travel
# 		semantic class id: 200757 label: means of travel
# 		semantic class id: 201351 label: a conveyance
# 		semantic class id: 201370 label: vehicle
# 		semantic class id: 202408 label: public service vehicle
# 		semantic class id: 202418 label: None
# 			word associated to this semantic class psv ( psv_nn01 )
# 		semantic class id: 202421 label: stagecoach or mail coach
# 			word associated to this semantic class diligence ( diligence_nn02 )
# 			word associated to this semantic class dilly ( dilly_nn01 )
# 			word associated to this semantic class fly ( fly_nn02 )
# 			word associated to this semantic class flying post ( flying_jj01 )
# 			word associated to this semantic class high-flyer ( highflyer_nn01 )
# 			word associated to this semantic class machine ( machine_nn01 )
# 			word associated to this semantic class mail coach ( mailcoach_nn01 )
# 			word associated to this semantic class mail-hack ( mailhack_nn01 )
# 			word associated to this semantic class mail packet ( mailpacket_nn01 )
# 			word associated to this semantic class mail stage ( mailstage_nn01 )
# 			word associated to this semantic class post calash ( postcalash_nn01 )
# 			word associated to this semantic class post-car ( postcar_nn01 )
# 			word associated to this semantic class post-carriage ( postcarriage_nn01 )
# 			word associated to this semantic class post-coach ( postcoach_nn01 )
# 			word associated to this semantic class post-equipage ( postequipage_nn01 )
# 			word associated to this semantic class post-stage ( poststage_nn01 )
# 			word associated to this semantic class post vehicle ( postvehicle_nn01 )
# 			word associated to this semantic class post-wagon ( postwagon_nn01 )
# 			word associated to this semantic class stage ( stage_nn01 )
# 			word associated to this semantic class stagecoach ( stagecoach_nn01 )
# 			word associated to this semantic class stager ( stager_nn01 )
# 			word associated to this semantic class stage-wagon ( stagewagon_nn01 )
# 			word associated to this semantic class tally-ho ( tallyho_uh01 )
# 			word associated to this semantic class wagon ( wagon_nn01 )
# 			word associated to this semantic class wagon-coach ( wagoncoach_nn01 )
# sense number 12
# definition: Mechanics. Anything that transmits force or directs its application.
# 	set of semantic classes number 0
# 		semantic class id: 153072 label: society
# 		semantic class id: 208185 label: occupation and work
# 		semantic class id: 211995 label: equipment
# 		semantic class id: 213839 label: machine
# 		semantic class id: 213903 label: machines which impart power
# 		semantic class id: 214198 label: None
# 			word associated to this semantic class energizer ( energizer_nn01 )
# 			word associated to this semantic class generator ( generator_nn01 )
# 			word associated to this semantic class machine ( machine_nn01 )
# 			word associated to this semantic class mover ( mover_nn01 )
# 			word associated to this semantic class prime mover ( primemover_nn01 )
# 			word associated to this semantic class primum mobile ( primummobile_nn01 )
# 			word associated to this semantic class vice ( vice_nn02 )
# 	set of semantic classes number 1
# 		semantic class id: 1 label: the world
# 		semantic class id: 67134 label: matter
# 		semantic class id: 75461 label: physics
# 		semantic class id: 75462 label: mechanics
# 		semantic class id: 75463 label: force
# 		semantic class id: 75580 label: None
# 			word associated to this semantic class force ( force_nn01 )
# 			word associated to this semantic class power ( power_nn01 )
# 		semantic class id: 75656 label: active mechanical force
# 			word associated to this semantic class effort ( effort_nn01 )
# 			word associated to this semantic class power ( power_nn01 )
# 		semantic class id: 75660 label: ratio of load to force applied
# 			word associated to this semantic class mechanical advantage ( mechanicaladvantage_nn01 )
# 		semantic class id: 75661 label: mechanical advantage by use of machine
# 			word associated to this semantic class machine ( machine_nn01 )
# 			word associated to this semantic class machine power ( machinepower_nn01 )
# 			word associated to this semantic class mechanical advantage ( mechanicaladvantage_nn01 )
# 			word associated to this semantic class power ( power_nn01 )
# sense number 13
# definition: slang. The penis; the female genitals (rare). Also: †a condom (obsolete).
# 	set of semantic classes number 0
# 		semantic class id: 1 label: the world
# 		semantic class id: 8835 label: life
# 		semantic class id: 25507 label: the body
# 		semantic class id: 28377 label: sex organs
# 		semantic class id: 28378 label: male sex organs
# 		semantic class id: 28384 label: None
# 			word associated to this semantic class button ( button_nn01 )
# 			word associated to this semantic class crown jewel ( crownjewel_nn01 )
# 			word associated to this semantic class emblems ( emblem_nn01 )
# 			word associated to this semantic class family jewels ( familyjewels_nn01 )
# 			word associated to this semantic class genital ( genital_nn01 )
# 			word associated to this semantic class genitalia ( genitalia_nn01 )
# 			word associated to this semantic class genitals ( genital_nn01 )
# 			word associated to this semantic class junk ( junk_nn01 )
# 			word associated to this semantic class lunchbox ( lunchbox_nn01 )
# 			word associated to this semantic class package ( package_nn01 )
# 			word associated to this semantic class virilities ( virility_nn01 )
# 			word associated to this semantic class virility ( virility_nn01 )
# 			word associated to this semantic class wally ( wally_nn01 )
# 		semantic class id: 28386 label: penis
# 			word associated to this semantic class Aaron's rod ( aaronsrod_nn01 )
# 			word associated to this semantic class arrow ( arrow_nn01 )
# 			word associated to this semantic class baby-maker ( babymaker_nn01 )
# 			word associated to this semantic class chode ( chode_nn01 )
# 			word associated to this semantic class cock ( cock_nn01 )
# 			word associated to this semantic class cod ( cod_nn01a )
# 			word associated to this semantic class dick ( dick_nn01 )
# 			word associated to this semantic class dicky ( dicky_nn02 )
# 			word associated to this semantic class dildo ( dildo_nn01 )
# 			word associated to this semantic class dildo ( dildo_nn01 )
# 			word associated to this semantic class ding-a-ling ( dingaling_nn01 )
# 			word associated to this semantic class dong ( dong_nn03 )
# 			word associated to this semantic class dork ( dork_nn01 )
# 			word associated to this semantic class engine ( engine_nn01 )
# 			word associated to this semantic class fidcock ( fidcock_nn01 )
# 			word associated to this semantic class flute ( flute_nn01 )
# 			word associated to this semantic class handle ( handle_nn01 )
# 			word associated to this semantic class instrument ( instrument_nn01 )
# 			word associated to this semantic class intromittent ( intromittent_jj01 )
# 			word associated to this semantic class jock ( jock_nn03 )
# 			word associated to this semantic class John ( john_nn01 )
# 			word associated to this semantic class John Henry ( johnhenry_nn01 )
# 			word associated to this semantic class Johnny ( johnny_nn01 )
# 			word associated to this semantic class Johnson ( johnson_nn01 )
# 			word associated to this semantic class John Thomas ( johnthomas_nn01 )
# 			word associated to this semantic class knob ( knob_nn01 )
# 			word associated to this semantic class langer ( langer_nn01 )
# 			word associated to this semantic class length ( length_nn01 )
# 			word associated to this semantic class loom ( loom_nn01 )
# 			word associated to this semantic class machine ( machine_nn01 )
# 			word associated to this semantic class manhood ( manhood_nn01 )
# 			word associated to this semantic class meat tool ( meattool_nn01 )
# 			word associated to this semantic class membrum virile ( membrumvirile_nn01 )
# 			word associated to this semantic class mentula ( mentula_nn01 )
# 			word associated to this semantic class mickey ( mickey_nn01 )
# 			word associated to this semantic class micky ( micky_nn01 )
# 			word associated to this semantic class middle leg ( middleleg_nn01 )
# 			word associated to this semantic class mole ( mole_nn03 )
# 			word associated to this semantic class monkey ( monkey_nn01 )
# 			word associated to this semantic class nag ( nag_nn01 )
# 			word associated to this semantic class needle ( needle_nn01 )
# 			word associated to this semantic class nerve ( nerve_nn01 )
# 			word associated to this semantic class noonies ( noonie_nn01 )
# 			word associated to this semantic class old fellow ( oldfellow_nn01 )
# 			word associated to this semantic class old man ( oldman_nn01 )
# 			word associated to this semantic class organ ( organ_nn01 )
# 			word associated to this semantic class other thing ( otherthing_nn01 )
# 			word associated to this semantic class pecker ( pecker_nn01 )
# 			word associated to this semantic class pee-pee ( peepee_nn02 )
# 			word associated to this semantic class pego ( pego_nn01 )
# 			word associated to this semantic class pencil ( pencil_nn01 )
# 			word associated to this semantic class penis ( penis_nn01 )
# 			word associated to this semantic class Percy ( percy_nn01 )
# 			word associated to this semantic class Peter ( peter_nn01 )
# 			word associated to this semantic class pillicock ( pillicock_nn01 )
# 			word associated to this semantic class pillock ( pillock_nn01 )
# 			word associated to this semantic class pintle ( pintle_nn01 )
# 			word associated to this semantic class pisser ( pisser_nn01 )
# 			word associated to this semantic class pizzle ( pizzle_nn01 )
# 			word associated to this semantic class poker ( poker_nn02 )
# 			word associated to this semantic class pork ( pork_nn01 )
# 			word associated to this semantic class prependent ( prependent_nn01 )
# 			word associated to this semantic class prick ( prick_nn01 )
# 			word associated to this semantic class privy ( privy_nn01 )
# 			word associated to this semantic class prong ( prong_nn02 )
# 			word associated to this semantic class propagator ( propagator_nn01 )
# 			word associated to this semantic class pud ( pud_nn02 )
# 			word associated to this semantic class pudding ( pudding_nn01 )
# 			word associated to this semantic class putz ( putz_nn02 )
# 			word associated to this semantic class quillity ( quillity_nn02 )
# 			word associated to this semantic class rammer ( rammer_nn01 )
# 			word associated to this semantic class rig ( rig_nn03 )
# 			word associated to this semantic class Roger ( roger_nn02 )
# 			word associated to this semantic class root ( root_nn01 )
# 			word associated to this semantic class rubigo ( rubigo_nn01 )
# 			word associated to this semantic class runnion ( runnion_nn01 )
# 			word associated to this semantic class schlong ( schlong_nn01 )
# 			word associated to this semantic class sex ( sex_nn01 )
# 			word associated to this semantic class shaft ( shaft_nn02 )
# 			word associated to this semantic class swipe ( swipe_nn02 )
# 			word associated to this semantic class tadger ( tadger_nn01 )
# 			word associated to this semantic class tarse ( tarse_nn01 )
# 			word associated to this semantic class tonk ( tonk_nn01 )
# 			word associated to this semantic class tool ( tool_nn01 )
# 			word associated to this semantic class tube ( tube_nn01 )
# 			word associated to this semantic class verge ( verge_nn01 )
# 			word associated to this semantic class virge ( virge_nn01 )
# 			word associated to this semantic class virile member ( virile_jj01 )
# 			word associated to this semantic class virilia ( virilia_nn01 )
# 			word associated to this semantic class virility ( virility_nn01 )
# 			word associated to this semantic class wanker ( wanker_nn01 )
# 			word associated to this semantic class weapon ( weapon_nn01 )
# 			word associated to this semantic class wee-wee ( weewee_nn01 )
# 			word associated to this semantic class whang ( whang_nn01 )
# 			word associated to this semantic class whanger ( whanger_nn02 )
# 			word associated to this semantic class whore-pipe ( whorepipe_nn01 )
# 			word associated to this semantic class willy ( willy_nn02 )
# 			word associated to this semantic class winkle ( winkle_nn01 )
# 			word associated to this semantic class winky ( winky_nn02 )
# 			word associated to this semantic class yard ( yard_nn02 )
# 	set of semantic classes number 1
# 		semantic class id: 1 label: the world
# 		semantic class id: 62186 label: physical sensation
# 		semantic class id: 62978 label: sexual relations
# 		semantic class id: 63430 label: contraception or birth control
# 		semantic class id: 63435 label: None
# 			word associated to this semantic class birth control ( birthcontrol_nn01 )
# 			word associated to this semantic class contraception ( contraception_nn01 )
# 			word associated to this semantic class family planning ( familyplanning_nn01 )
# 		semantic class id: 63438 label: contraceptive device
# 			word associated to this semantic class contraceptive ( contraceptive_nn01 )
# 			word associated to this semantic class precaution ( precaution_nn01 )
# 			word associated to this semantic class preventative ( preventative_nn01 )
# 			word associated to this semantic class preventive ( preventive_nn01 )
# 			word associated to this semantic class protection ( protection_nn01 )
# 		semantic class id: 63441 label: condom
# 			word associated to this semantic class armour ( armour_nn01 )
# 			word associated to this semantic class condom ( condom_nn01 )
# 			word associated to this semantic class Durex ( durex_nn02 )
# 			word associated to this semantic class French letter ( frenchletter_nn01 )
# 			word associated to this semantic class Frenchy ( frenchy_nn01 )
# ...
# 			word associated to this semantic class power ( power_nn01 )
# 			word associated to this semantic class tram ( tram_nn01 )
# 		semantic class id: 214574 label: specific machine with which speaker is concerned
# 			word associated to this semantic class machine ( machine_nn01 )
# sense number 16
# definition: A bicycle or tricycle; a motorcycle. Formerly also: a dandy-horse or velocipede (now historical).
# 	set of semantic classes number 0
# 		semantic class id: 153072 label: society
# 		semantic class id: 198379 label: travel
# 		semantic class id: 200757 label: means of travel
# 		semantic class id: 201351 label: a conveyance
# 		semantic class id: 201370 label: vehicle
# 		semantic class id: 201563 label: vehicle propelled by feet
# 		semantic class id: 201573 label: None
# 			word associated to this semantic class pedomotive ( pedomotive_nn01 )
# 			word associated to this semantic class pedomotor ( pedomotor_nn01 )
# 		semantic class id: 201575 label: cycle
# 			word associated to this semantic class cycle ( cycle_nn02 )
# 			word associated to this semantic class cycle ( cycle_nn01 )
# 			word associated to this semantic class horse ( horse_nn01 )
# 			word associated to this semantic class machine ( machine_nn01 )
# 			word associated to this semantic class wheel ( wheel_nn01 )
# sense number 17
# definition: U.S. colloquial. A fire engine. Obsolete.
# 	set of semantic classes number 0
# 		semantic class id: 1 label: the world
# 		semantic class id: 67134 label: matter
# 		semantic class id: 71763 label: properties of materials
# 		semantic class id: 71864 label: temperature
# 		semantic class id: 72718 label: coldness
# 		semantic class id: 72764 label: extinguishing fire
# 		semantic class id: 72775 label: None
# 			word associated to this semantic class blesching ( blesching_nn01 )
# 			word associated to this semantic class extinction ( extinction_nn01 )
# 			word associated to this semantic class extincture ( extincture_nn01 )
# 			word associated to this semantic class extinguishment ( extinguishment_nn01 )
# 			word associated to this semantic class fire-extinguishing ( fireextinguishing_nn01 )
# 			word associated to this semantic class quench ( quench_nn01 )
# 			word associated to this semantic class quenchour ( quenchour_nn01 )
# 			word associated to this semantic class slecking ( slecking_nn01 )
# 			word associated to this semantic class slockening ( slockening_nn01 )
# 		semantic class id: 72778 label: fire-fighting
# 			word associated to this semantic class firefighting ( firefighting_nn01 )
# 		semantic class id: 72790 label: a substance or apparatus for extinguishing
# 			word associated to this semantic class extinguishment ( extinguishment_nn01 )
# 			word associated to this semantic class quench-fire ( quenchfire_nn01 )
# 		semantic class id: 72805 label: fire-engine
# 			word associated to this semantic class appliance ( appliance_nn01 )
# 			word associated to this semantic class engine ( engine_nn01 )
# 			word associated to this semantic class fire engine ( fireengine_nn01 )
# 			word associated to this semantic class forcing-engine ( forcingengine_nn01 )
# 			word associated to this semantic class machine ( machine_nn01 )
# 			word associated to this semantic class tub ( tub_nn01 )
# 			word associated to this semantic class water engine ( waterengine_nn01 )
# sense number 18
# definition: Originally U.S. The controlling organization of a political party or similar body; any organization or group displaying impressive or ruthless efficiency.
# 	set of semantic classes number 0
# 		semantic class id: 153072 label: society
# 		semantic class id: 165531 label: authority
# 		semantic class id: 166197 label: rule or government
# 		semantic class id: 168151 label: politics
# 		semantic class id: 168217 label: party politics
# 		semantic class id: 168326 label: None
# 			word associated to this semantic class party ( party_nn01 )
# 			word associated to this semantic class party politics ( partypolitics_nn01 )
# 			word associated to this semantic class party system ( partysystem_nn01 )
# 		semantic class id: 168344 label: party machine
# 			word associated to this semantic class machine ( machine_nn01 )
# sense number 19
# definition: A box or case in which fresh fish are sold wholesale. Cf. trunk n. 8b. Obsolete.
# 	set of semantic classes number 0
# 		semantic class id: 1 label: the world
# 		semantic class id: 45969 label: food and drink
# 		semantic class id: 45970 label: food
# 		semantic class id: 46185 label: animals for food
# 		semantic class id: 46320 label: seafood
# 		semantic class id: 46337 label: None
# 			word associated to this semantic class sea-fare ( seafare_nn01 )
# 			word associated to this semantic class seafood ( seafood_nn01 )
# 		semantic class id: 46338 label: fish
# 			word associated to this semantic class cetaries ( cetaries_nn01 )
# 			word associated to this semantic class dogfish ( dogfish_nn01 )
# 			word associated to this semantic class fish ( fish_nn01 )
# 			word associated to this semantic class fishery ( fishery_nn01 )
# 			word associated to this semantic class fish food ( fishfood_nn01 )
# 			word associated to this semantic class meat fish ( meatfish_nn01 )
# 		semantic class id: 46370 label: quantity of fish
# 			word associated to this semantic class bind ( bind_nn01 )
# 			word associated to this semantic class cast ( cast_nn01 )
# 			word associated to this semantic class cran ( cran_nn01 )
# 			word associated to this semantic class mease ( mease_nn01 )
# 			word associated to this semantic class stick ( stick_nn01 )
# 			word associated to this semantic class strike ( strike_nn02 )
# 			word associated to this semantic class swill ( swill_nn01 )
# 			word associated to this semantic class toss ( toss_nn01 )
# 			word associated to this semantic class turn ( turn_nn01 )
# 			word associated to this semantic class warp ( warp_nn01 )
# 			word associated to this semantic class wisp ( wisp_nn01 )
# 		semantic class id: 46371 label: container for
# 			word associated to this semantic class cade ( cade_nn01 )
# 			word associated to this semantic class cran ( cran_nn01 )
# 			word associated to this semantic class machine ( machine_nn01 )
# 			word associated to this semantic class stick ( stick_nn02 )
# 			word associated to this semantic class swill ( swill_nn01 )
# 			word associated to this semantic class trunk ( trunk_nn01 )
# sense number 20
# definition: Australian and New Zealand colloquial. A totalizator.
# 	set of semantic classes number 0
# 		semantic class id: 153072 label: society
# 		semantic class id: 222360 label: leisure
# 		semantic class id: 222361 label: entertainment
# 		semantic class id: 222459 label: pastimes
# 		semantic class id: 223668 label: betting
# 		semantic class id: 223702 label: None
# 			word associated to this semantic class betting ( betting_nn01 )
# 			word associated to this semantic class gambling ( gambling_nn01 )
# 			word associated to this semantic class wagering ( wagering_nn01 )
# 			word associated to this semantic class wedding ( wedding_nn01 )
# 		semantic class id: 223744 label: book-maker's equipment
# 			word associated to this semantic class joint ( joint_nn01 )
# 		semantic class id: 223746 label: totalizator
# 			word associated to this semantic class machine ( machine_nn01 )
# 			word associated to this semantic class nanny ( nanny_nn02 )
# 			word associated to this semantic class nanny-goat ( nannygoat_nn01 )
# 			word associated to this semantic class totalizator ( totalizator_nn01 )
# 			word associated to this semantic class totalizer ( totalizer_nn01 )
# 			word associated to this semantic class totalizing ( totalizing_nn01 )
# 			word associated to this semantic class tote ( tote_nn01 )
# sense number 21
# definition: An aircraft or airship. Cf. sense 6b.
# 	set of semantic classes number 0
# 		semantic class id: 153072 label: society
# 		semantic class id: 198379 label: travel
# 		semantic class id: 206909 label: air or space travel
# 		semantic class id: 207619 label: a means of conveyance through the air
# 		semantic class id: 208130 label: None
# 			word associated to this semantic class waftage ( waftage_nn01 )
# 		semantic class id: 208136 label: an aircraft
# 			word associated to this semantic class aerobat ( aerobat_nn01 )
# 			word associated to this semantic class aerocar ( aerocar_nn01 )
# 			word associated to this semantic class aerostat ( aerostat_nn01 )
# 			word associated to this semantic class aircraft ( aircraft_nn01 )
# 			word associated to this semantic class air machine ( airmachine_nn01 )
# 			word associated to this semantic class air vessel ( airvessel_nn01 )
# 			word associated to this semantic class avion ( avion_nn01 )
# 			word associated to this semantic class clipper ( clipper_nn01 )
# 			word associated to this semantic class flyer ( flyer_nn01 )
# 			word associated to this semantic class machine ( machine_nn01 )
# sense number 22
# definition: Originally and chiefly U.S. A motor vehicle, esp. a car.
# 	set of semantic classes number 0
# 		semantic class id: 153072 label: society
# 		semantic class id: 198379 label: travel
# 		semantic class id: 200757 label: means of travel
# 		semantic class id: 201351 label: a conveyance
# 		semantic class id: 201370 label: vehicle
# 		semantic class id: 201885 label: powered vehicle
# 		semantic class id: 202077 label: motor car
# 		semantic class id: 202100 label: None
# 			word associated to this semantic class bubble ( bubble_nn01 )
# 			word associated to this semantic class buggy ( buggy_nn01 )
# 			word associated to this semantic class bus ( bus_nn01 )
# 			word associated to this semantic class buzz-box ( buzzbox_nn01 )
# 			word associated to this semantic class buzz-wagon ( buzzwagon_nn01 )
# 			word associated to this semantic class car ( car_nn01 )
# 			word associated to this semantic class drag ( drag_nn01 )
# 			word associated to this semantic class jam-jar ( jamjar_nn01 )
# 			word associated to this semantic class Lizzie ( lizzie_nn01 )
# 			word associated to this semantic class low rider ( lowrider_nn01 )
# 			word associated to this semantic class machine ( machine_nn01 )
# 			word associated to this semantic class motor ( motor_nn01 )
# 			word associated to this semantic class motor car ( motorcar_nn01 )
# 			word associated to this semantic class motor carriage ( motorcarriage_nn01 )
# 			word associated to this semantic class ride ( ride_nn02 )
# 			word associated to this semantic class scoot ( scoot_nn03 )
# 			word associated to this semantic class scooter ( scooter_nn01 )
# 			word associated to this semantic class short ( short_nn01 )
# 			word associated to this semantic class traction ( traction_nn01 )
# 			word associated to this semantic class wagon ( wagon_nn01 )
# 			word associated to this semantic class wheels ( wheel_nn01 )
# sense number 23
# definition: Painting. A painting of large size, esp. one whose subject matter and composition are complicated, contrived, or exaggerated.
# 	set of semantic classes number 0
# 		semantic class id: 153072 label: society
# 		semantic class id: 222360 label: leisure
# 		semantic class id: 224508 label: the arts
# 		semantic class id: 227402 label: visual arts
# 		semantic class id: 227682 label: painting and drawing
# 		semantic class id: 227729 label: painting
# 		semantic class id: 228006 label: None
# 			word associated to this semantic class brush ( brush_nn02 )
# 			word associated to this semantic class depaint ( depaint_nn01 )
# 			word associated to this semantic class imagery ( imagery_nn01 )
# 			word associated to this semantic class limning ( limning_nn01 )
# 			word associated to this semantic class painting ( painting_nn01 )
# 			word associated to this semantic class painture ( painture_nn01 )
# 			word associated to this semantic class pencil ( pencil_nn01 )
# 			word associated to this semantic class scene painting ( scenepainting_nn01 )
# 		semantic class id: 228009 label: a painting
# 			word associated to this semantic class colouring ( colouring_nn01 )
# 			word associated to this semantic class limning ( limning_nn01 )
# 			word associated to this semantic class paint ( paint_nn01 )
# 			word associated to this semantic class painting ( painting_nn01 )
# 			word associated to this semantic class paintry ( paintry_nn01 )
# 			word associated to this semantic class painture ( painture_nn01 )
# 			word associated to this semantic class tablature ( tablature_nn01 )
# 			word associated to this semantic class tableau ( tableau_nn01 )
# 		semantic class id: 228011 label: of specific size or shape
# 			word associated to this semantic class easel-picture ( easelpicture_nn01 )
# 			word associated to this semantic class easel-piece ( easelpiece_nn01 )
# 			word associated to this semantic class kakemono ( kakemono_nn01 )
# 			word associated to this semantic class machine ( machine_nn01 )
# 			word associated to this semantic class micrograph ( micrograph_nn01 )
# 			word associated to this semantic class pata ( pata_nn01 )
# 			word associated to this semantic class quadrant ( quadrant_nn02 )
# 			word associated to this semantic class scroll painting ( scrollpainting_nn01 )
# 			word associated to this semantic class scroll picture ( scrollpicture_nn01 )
# 			word associated to this semantic class tondo ( tondo_nn01 )
# sense number 24
# definition: figurative.machine for living (in): a house or other habitation considered as a functional entity. Also in imitative phrases.
# 	set of semantic classes number 0
# 		semantic class id: 153072 label: society
# 		semantic class id: 157909 label: inhabiting and dwelling
# 		semantic class id: 158520 label: inhabited place
# 		semantic class id: 158897 label: dwelling place or abode
# 		semantic class id: 158994 label: a dwelling
# 		semantic class id: 158995 label: a house
# 		semantic class id: 159066 label: None
# 			word associated to this semantic class being ( being_nn01 )
# 			word associated to this semantic class bike ( bike_nn01 )
# 			word associated to this semantic class casa ( casa_nn02 )
# 			word associated to this semantic class drum ( drum_nn03 )
# 			word associated to this semantic class dwelling-house ( dwellinghouse_nn01 )
# 			word associated to this semantic class firehouse ( firehouse_nn01 )
# 			word associated to this semantic class home ( home_nn01 )
# 			word associated to this semantic class house ( house_nn01 )
# 			word associated to this semantic class house ( house_nn01 )
# 			word associated to this semantic class housing ( housing_nn01 )
# 			word associated to this semantic class khazi ( khazi_nn01 )
# 			word associated to this semantic class kipsie ( kipsie_nn01 )
# 			word associated to this semantic class longhouse ( longhouse_nn01 )
# 			word associated to this semantic class machine for living ( machine_nn01 )
# 			word associated to this semantic class maison ( maison_nn01 )
# 			word associated to this semantic class mansion house ( mansionhouse_nn01 )
# 			word associated to this semantic class roof ( roof_nn01 )
# 			word associated to this semantic class shack ( shack_nn03 )
# 			word associated to this semantic class smoke-house ( smokehouse_nn01 )
# 			word associated to this semantic class standing house ( standing_jj01 )
# sense number 25
# definition: A conceptual, abstract, or theoretical mechanism or device; spec. a model or a mathematical abstraction of an existing or hypothetical computer. Cf. Turing machine n.
# 	set of semantic classes number 0
# 		semantic class id: 153072 label: society
# 		semantic class id: 116218 label: computing and information technology
# 		semantic class id: 116219 label: hardware
# 		semantic class id: 116319 label: computer
# 		semantic class id: 116331 label: None
# 			word associated to this semantic class computator ( computator_nn01 )
# 			word associated to this semantic class computer ( computer_nn01 )
# 			word associated to this semantic class computer system ( computersystem_nn01 )
# 			word associated to this semantic class computor ( computor_nn01 )
# 			word associated to this semantic class data processor ( dataprocessor_nn01 )
# 			word associated to this semantic class system ( system_nn01 )
# 		semantic class id: 116332 label: notional
# 			word associated to this semantic class biocomputer ( biocomputer_nn01 )
# 			word associated to this semantic class machine ( machine_nn01 )
# 			word associated to this semantic class Turing machine ( turingmachine_nn01 )
